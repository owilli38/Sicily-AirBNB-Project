# %%
import pandas as pd
import geopandas as gpd

# %%
df1 = pd.read_csv('/content/calendar.csv.gz')
df2 = pd.read_csv('/content/listings.csv.gz')
df3 = pd.read_csv('/content/neighbourhoods.csv')
df4 = pd.read_csv('/content/reviews.csv.gz', quoting=3, on_bad_lines='warn')
df5 = gpd.read_file('/content/neighbourhoods.geojson')
# Out:
# Streaming output truncated to the last 5000 lines.
# Skipping line 1089805: expected 12 fields, saw 13
# Skipping line 1089829: expected 12 fields, saw 13
# Skipping line 1089831: expected 12 fields, saw 13
# Skipping line 1089839: expected 12 fields, saw 13
# Skipping line 1089840: expected 12 fields, saw 14
# Skipping line 1089857: expected 12 fields, saw 18
# Skipping line 1089874: expected 12 fields, saw 14
# Skipping line 1089882: expected 12 fields, saw 14
# Skipping line 1089893: expected 12 fields, saw 22
# Skipping line 1089899: expected 12 fields, saw 13
# Skipping line 1089912: expected 12 fields, saw 13
# Skipping line 1089923: expected 12 fields, saw 14
# Skipping line 1089937: expected 12 fields, saw 14
# Skipping line 1089941: expected 12 fields, saw 15
# Skipping line 1089944: expected 12 fields, saw 13
# Skipping line 1089977: expected 12 fields, saw 15
# Skipping line 1089989: expected 12 fields, saw 17
# Skipping line 1089996: expected 12 fields, saw 14
# Skipping line 1090019: expected 12 fields, saw 15
# Skipping line 1090022: expected 12 fields, saw 13
# Skipping line 1090040: expected 12 fields, saw 16
# Skipping line 1090066: expected 12 fields, saw 13
# Skipping line 1090088: expected 12 fields, saw 14
# Skipping line 1090095: expected 12 fields, saw 16
# Skipping line 1090101: expected 12 fields, saw 20
# Skipping line 1090119: expected 12 fields, saw 14
# Skipping line 1090126: expected 12 fields, saw 13
# Skipping line 1090150: expected 12 fields, saw 13
# Skipping line 1090161: expected 12 fields, saw 13
# Skipping line 1090183: expected 12 fields, saw 17
# Skipping line 1090213: expected 12 fields, saw 14
# Skipping line 1090217: expected 12 fields, saw 13
# Skipping line 1090225: expected 12 fields, saw 16
# Skipping line 1090231: expected 12 fields, saw 17
# Skipping line 1090287: expected 12 fields, saw 19
# Skipping line 1090297: expected 12 fields, saw 20
# Skipping line 1090302: expected 12 fields, saw 13
# Skipping line 1090303: expected 12 fields, saw 13
# Skipping line 1090309: expected 12 fields, saw 13
# Skipping line 1090323: expected 12 fields, saw 13
# Skipping line 1090328: expected 12 fields, saw 14
# Skipping line 1090333: expected 12 fields, saw 13
# Skipping line 1090355: expected 12 fields, saw 22
# Skipping line 1090359: expected 12 fields, saw 15
# Skipping line 1090402: expected 12 fields, saw 13
# Skipping line 1090412: expected 12 fields, saw 13
# Skipping line 1090427: expected 12 fields, saw 20
# Skipping line 1090494: expected 12 fields, saw 13
# Skipping line 1090505: expected 12 fields, saw 13
# Skipping line 1090512: expected 12 fields, saw 20
# Skipping line 1090513: expected 12 fields, saw 13
# Skipping line 1090520: expected 12 fields, saw 13
# Skipping line 1090521: expected 12 fields, saw 14
# Skipping line 1090528: expected 12 fields, saw 14
# Skipping line 1090540: expected 12 fields, saw 13
# Skipping line 1090570: expected 12 fields, saw 19
# Skipping line 1090585: expected 12 fields, saw 20
# Skipping line 1090600: expected 12 fields, saw 17
# Skipping line 1090613: expected 12 fields, saw 16
# Skipping line 1090646: expected 12 fields, saw 13
# Skipping line 1090658: expected 12 fields, saw 13
# Skipping line 1090671: expected 12 fields, saw 14
# Skipping line 1090699: expected 12 fields, saw 18
# Skipping line 1090713: expected 12 fields, saw 18
# Skipping line 1090715: expected 12 fields, saw 15
# Skipping line 1090717: expected 12 fields, saw 20
# Skipping line 1090718: expected 12 fields, saw 15
# Skipping line 1090719: expected 12 fields, saw 13
# Skipping line 1090738: expected 12 fields, saw 20
# Skipping line 1090742: expected 12 fields, saw 13
# Skipping line 1090752: expected 12 fields, saw 19
# Skipping line 1090758: expected 12 fields, saw 14
# Skipping line 1090828: expected 12 fields, saw 13
# Skipping line 1090832: expected 12 fields, saw 13
# Skipping line 1090849: expected 12 fields, saw 13
# Skipping line 1090892: expected 12 fields, saw 15
# Skipping line 1090991: expected 12 fields, saw 22
# Skipping line 1091004: expected 12 fields, saw 17
# Skipping line 1091033: expected 12 fields, saw 15
# Skipping line 1091041: expected 12 fields, saw 17
# Skipping line 1091083: expected 12 fields, saw 14
# Skipping line 1091148: expected 12 fields, saw 14
# Skipping line 1091184: expected 12 fields, saw 25
# Skipping line 1091197: expected 12 fields, saw 13
# Skipping line 1091210: expected 12 fields, saw 15
# Skipping line 1091244: expected 12 fields, saw 15
# Skipping line 1091258: expected 12 fields, saw 14
# Skipping line 1091261: expected 12 fields, saw 16
# Skipping line 1091265: expected 12 fields, saw 14
# Skipping line 1091295: expected 12 fields, saw 15
# Skipping line 1091316: expected 12 fields, saw 13
# Skipping line 1091326: expected 12 fields, saw 14
# Skipping line 1091328: expected 12 fields, saw 15
# Skipping line 1091337: expected 12 fields, saw 13
# Skipping line 1091422: expected 12 fields, saw 15
# Skipping line 1091429: expected 12 fields, saw 21
# Skipping line 1091485: expected 12 fields, saw 14
# Skipping line 1091494: expected 12 fields, saw 14
# Skipping line 1091513: expected 12 fields, saw 13
# Skipping line 1091527: expected 12 fields, saw 15
# Skipping line 1091535: expected 12 fields, saw 17
# Skipping line 1091539: expected 12 fields, saw 13
# Skipping line 1091557: expected 12 fields, saw 19
# Skipping line 1091585: expected 12 fields, saw 15
# Skipping line 1091610: expected 12 fields, saw 13
# Skipping line 1091618: expected 12 fields, saw 14
# Skipping line 1091631: expected 12 fields, saw 13
# Skipping line 1091639: expected 12 fields, saw 13
# Skipping line 1091652: expected 12 fields, saw 14
# Skipping line 1091684: expected 12 fields, saw 13
# Skipping line 1091750: expected 12 fields, saw 13
# Skipping line 1091760: expected 12 fields, saw 15
# Skipping line 1091793: expected 12 fields, saw 19
# Skipping line 1091797: expected 12 fields, saw 13
# Skipping line 1091813: expected 12 fields, saw 13
# Skipping line 1091814: expected 12 fields, saw 13
# Skipping line 1091823: expected 12 fields, saw 16
# Skipping line 1091826: expected 12 fields, saw 16
# Skipping line 1091834: expected 12 fields, saw 14
# Skipping line 1091845: expected 12 fields, saw 14
# Skipping line 1091856: expected 12 fields, saw 14
# Skipping line 1091923: expected 12 fields, saw 14
# Skipping line 1091944: expected 12 fields, saw 16
# Skipping line 1091961: expected 12 fields, saw 17
# Skipping line 1091988: expected 12 fields, saw 16
# Skipping line 1091999: expected 12 fields, saw 16
# Skipping line 1092016: expected 12 fields, saw 13
# Skipping line 1092024: expected 12 fields, saw 18
# Skipping line 1092035: expected 12 fields, saw 14
# Skipping line 1092069: expected 12 fields, saw 16
# Skipping line 1092097: expected 12 fields, saw 13
# Skipping line 1092100: expected 12 fields, saw 13
# Skipping line 1092116: expected 12 fields, saw 14
# Skipping line 1092132: expected 12 fields, saw 15
# Skipping line 1092134: expected 12 fields, saw 16
# Skipping line 1092135: expected 12 fields, saw 13
# Skipping line 1092160: expected 12 fields, saw 19
# Skipping line 1092164: expected 12 fields, saw 17
# Skipping line 1092168: expected 12 fields, saw 13
# Skipping line 1092187: expected 12 fields, saw 13
# Skipping line 1092195: expected 12 fields, saw 18
# Skipping line 1092219: expected 12 fields, saw 17
# Skipping line 1092220: expected 12 fields, saw 14
# Skipping line 1092226: expected 12 fields, saw 14
# Skipping line 1092234: expected 12 fields, saw 14
# Skipping line 1092241: expected 12 fields, saw 14
# Skipping line 1092257: expected 12 fields, saw 15
# Skipping line 1092260: expected 12 fields, saw 14
# Skipping line 1092263: expected 12 fields, saw 14
# Skipping line 1092285: expected 12 fields, saw 13
# Skipping line 1092288: expected 12 fields, saw 14
# Skipping line 1092289: expected 12 fields, saw 20
# Skipping line 1092325: expected 12 fields, saw 13
# Skipping line 1092333: expected 12 fields, saw 14
# Skipping line 1092346: expected 12 fields, saw 15
# Skipping line 1092354: expected 12 fields, saw 14
# Skipping line 1092367: expected 12 fields, saw 14
# Skipping line 1092387: expected 12 fields, saw 22
# Skipping line 1092398: expected 12 fields, saw 24
# Skipping line 1092426: expected 12 fields, saw 13
# Skipping line 1092456: expected 12 fields, saw 14
# Skipping line 1092464: expected 12 fields, saw 13
# Skipping line 1092486: expected 12 fields, saw 13
# Skipping line 1092489: expected 12 fields, saw 13
# Skipping line 1092493: expected 12 fields, saw 20
# Skipping line 1092523: expected 12 fields, saw 14
# Skipping line 1092530: expected 12 fields, saw 13
# Skipping line 1092531: expected 12 fields, saw 13
# Skipping line 1092538: expected 12 fields, saw 15
# Skipping line 1092540: expected 12 fields, saw 14
# Skipping line 1092550: expected 12 fields, saw 16
# Skipping line 1092572: expected 12 fields, saw 15
# Skipping line 1092595: expected 12 fields, saw 14
# Skipping line 1092662: expected 12 fields, saw 15
# Skipping line 1092698: expected 12 fields, saw 13
# Skipping line 1092703: expected 12 fields, saw 16
# Skipping line 1092708: expected 12 fields, saw 14
# Skipping line 1092729: expected 12 fields, saw 13
# Skipping line 1092735: expected 12 fields, saw 13
# Skipping line 1092738: expected 12 fields, saw 13
# Skipping line 1092794: expected 12 fields, saw 14
# Skipping line 1092814: expected 12 fields, saw 18
# Skipping line 1092821: expected 12 fields, saw 14
# Skipping line 1092838: expected 12 fields, saw 16
# Skipping line 1092858: expected 12 fields, saw 15
# Skipping line 1092859: expected 12 fields, saw 20
# Skipping line 1092870: expected 12 fields, saw 13
# Skipping line 1092881: expected 12 fields, saw 15
# Skipping line 1092890: expected 12 fields, saw 15
# Skipping line 1092900: expected 12 fields, saw 14
# Skipping line 1092914: expected 12 fields, saw 14
# Skipping line 1092926: expected 12 fields, saw 13
# Skipping line 1092928: expected 12 fields, saw 15
# Skipping line 1092989: expected 12 fields, saw 13
# Skipping line 1093005: expected 12 fields, saw 16
# Skipping line 1093016: expected 12 fields, saw 30
# Skipping line 1093027: expected 12 fields, saw 14
# Skipping line 1093083: expected 12 fields, saw 13
# Skipping line 1093114: expected 12 fields, saw 13
# Skipping line 1093126: expected 12 fields, saw 19
# Skipping line 1093133: expected 12 fields, saw 13
# Skipping line 1093140: expected 12 fields, saw 17
# Skipping line 1093143: expected 12 fields, saw 13
# Skipping line 1093148: expected 12 fields, saw 17
# Skipping line 1093153: expected 12 fields, saw 13
# Skipping line 1093176: expected 12 fields, saw 13
# Skipping line 1093180: expected 12 fields, saw 15
# Skipping line 1093190: expected 12 fields, saw 23
# Skipping line 1093233: expected 12 fields, saw 13
# Skipping line 1093258: expected 12 fields, saw 14
# Skipping line 1093268: expected 12 fields, saw 14
# Skipping line 1093280: expected 12 fields, saw 13
# Skipping line 1093286: expected 12 fields, saw 16
# Skipping line 1093294: expected 12 fields, saw 13
# Skipping line 1093351: expected 12 fields, saw 16
# Skipping line 1093391: expected 12 fields, saw 13
# Skipping line 1093407: expected 12 fields, saw 13
# Skipping line 1093415: expected 12 fields, saw 19
# Skipping line 1093418: expected 12 fields, saw 15
# Skipping line 1093434: expected 12 fields, saw 17
# Skipping line 1093435: expected 12 fields, saw 14
# Skipping line 1093436: expected 12 fields, saw 16
# Skipping line 1093442: expected 12 fields, saw 19
# Skipping line 1093448: expected 12 fields, saw 16
# Skipping line 1093452: expected 12 fields, saw 15
# Skipping line 1093453: expected 12 fields, saw 13
# Skipping line 1093459: expected 12 fields, saw 13
# Skipping line 1093479: expected 12 fields, saw 17
# Skipping line 1093491: expected 12 fields, saw 15
# Skipping line 1093522: expected 12 fields, saw 14
# Skipping line 1093540: expected 12 fields, saw 18
# Skipping line 1093547: expected 12 fields, saw 15
# Skipping line 1093573: expected 12 fields, saw 16
# Skipping line 1093599: expected 12 fields, saw 16
# Skipping line 1093606: expected 12 fields, saw 16
# Skipping line 1093607: expected 12 fields, saw 18
# Skipping line 1093610: expected 12 fields, saw 15
# Skipping line 1093611: expected 12 fields, saw 13
# Skipping line 1093644: expected 12 fields, saw 15
# Skipping line 1093651: expected 12 fields, saw 20
# Skipping line 1093665: expected 12 fields, saw 17
# Skipping line 1093670: expected 12 fields, saw 13
# Skipping line 1093674: expected 12 fields, saw 14
# Skipping line 1093740: expected 12 fields, saw 13
# Skipping line 1093756: expected 12 fields, saw 13
# Skipping line 1093758: expected 12 fields, saw 13
# Skipping line 1093762: expected 12 fields, saw 15
# Skipping line 1093800: expected 12 fields, saw 17
# Skipping line 1093817: expected 12 fields, saw 18
# Skipping line 1093860: expected 12 fields, saw 13
# Skipping line 1093889: expected 12 fields, saw 18
# Skipping line 1093998: expected 12 fields, saw 15
# Skipping line 1094013: expected 12 fields, saw 17
# Skipping line 1094023: expected 12 fields, saw 13
# Skipping line 1094035: expected 12 fields, saw 13
# Skipping line 1094099: expected 12 fields, saw 15
# Skipping line 1094104: expected 12 fields, saw 14
# Skipping line 1094167: expected 12 fields, saw 13
# Skipping line 1094214: expected 12 fields, saw 16
# Skipping line 1094236: expected 12 fields, saw 14
# Skipping line 1094246: expected 12 fields, saw 17
# Skipping line 1094253: expected 12 fields, saw 13
# Skipping line 1094266: expected 12 fields, saw 13
# Skipping line 1094269: expected 12 fields, saw 13
# Skipping line 1094365: expected 12 fields, saw 19
# Skipping line 1094388: expected 12 fields, saw 17
# Skipping line 1094391: expected 12 fields, saw 15
# Skipping line 1094411: expected 12 fields, saw 13
# Skipping line 1094420: expected 12 fields, saw 15
# Skipping line 1094425: expected 12 fields, saw 18
# Skipping line 1094427: expected 12 fields, saw 13
# Skipping line 1094433: expected 12 fields, saw 14
# Skipping line 1094440: expected 12 fields, saw 13
# Skipping line 1094452: expected 12 fields, saw 13
# Skipping line 1094522: expected 12 fields, saw 15
# Skipping line 1094529: expected 12 fields, saw 14
# Skipping line 1094541: expected 12 fields, saw 13
# Skipping line 1094560: expected 12 fields, saw 14
# Skipping line 1094572: expected 12 fields, saw 13
# Skipping line 1094583: expected 12 fields, saw 13
# Skipping line 1094614: expected 12 fields, saw 13
# Skipping line 1094622: expected 12 fields, saw 14
# Skipping line 1094634: expected 12 fields, saw 16
# Skipping line 1094637: expected 12 fields, saw 16
# Skipping line 1094663: expected 12 fields, saw 15
# Skipping line 1094678: expected 12 fields, saw 13
# Skipping line 1094697: expected 12 fields, saw 16
# Skipping line 1094702: expected 12 fields, saw 14
# Skipping line 1094754: expected 12 fields, saw 14
# Skipping line 1094783: expected 12 fields, saw 14
# Skipping line 1094785: expected 12 fields, saw 13
# Skipping line 1094794: expected 12 fields, saw 13
# Skipping line 1094843: expected 12 fields, saw 15
# Skipping line 1094868: expected 12 fields, saw 15
# Skipping line 1094880: expected 12 fields, saw 13
# Skipping line 1094908: expected 12 fields, saw 13
# Skipping line 1094953: expected 12 fields, saw 13
# Skipping line 1094954: expected 12 fields, saw 13
# Skipping line 1094959: expected 12 fields, saw 14
# Skipping line 1095011: expected 12 fields, saw 13
# Skipping line 1095037: expected 12 fields, saw 14
# Skipping line 1095042: expected 12 fields, saw 13
# Skipping line 1095061: expected 12 fields, saw 13
# Skipping line 1095139: expected 12 fields, saw 17
# Skipping line 1095166: expected 12 fields, saw 14
# Skipping line 1095238: expected 12 fields, saw 13
# Skipping line 1095275: expected 12 fields, saw 16
# Skipping line 1095286: expected 12 fields, saw 14
# Skipping line 1095295: expected 12 fields, saw 15
# Skipping line 1095309: expected 12 fields, saw 17
# Skipping line 1095320: expected 12 fields, saw 13
# Skipping line 1095343: expected 12 fields, saw 14
# Skipping line 1095345: expected 12 fields, saw 13
# Skipping line 1095347: expected 12 fields, saw 13
# Skipping line 1095352: expected 12 fields, saw 15
# Skipping line 1095364: expected 12 fields, saw 15
# Skipping line 1095380: expected 12 fields, saw 13
# Skipping line 1095417: expected 12 fields, saw 14
# Skipping line 1095430: expected 12 fields, saw 13
# Skipping line 1095434: expected 12 fields, saw 23
# Skipping line 1095443: expected 12 fields, saw 14
# Skipping line 1095446: expected 12 fields, saw 15
# Skipping line 1095460: expected 12 fields, saw 16
# Skipping line 1095470: expected 12 fields, saw 13
# Skipping line 1095518: expected 12 fields, saw 16
# Skipping line 1095524: expected 12 fields, saw 13
# Skipping line 1095539: expected 12 fields, saw 16
# Skipping line 1095568: expected 12 fields, saw 19
# Skipping line 1095570: expected 12 fields, saw 13
# Skipping line 1095584: expected 12 fields, saw 23
# Skipping line 1095597: expected 12 fields, saw 13
# Skipping line 1095614: expected 12 fields, saw 13
# Skipping line 1095629: expected 12 fields, saw 17
# Skipping line 1095637: expected 12 fields, saw 15
# Skipping line 1095643: expected 12 fields, saw 21
# Skipping line 1095668: expected 12 fields, saw 15
# Skipping line 1095672: expected 12 fields, saw 13
# Skipping line 1095680: expected 12 fields, saw 17
# Skipping line 1095681: expected 12 fields, saw 16
# Skipping line 1095684: expected 12 fields, saw 14
# Skipping line 1095790: expected 12 fields, saw 15
# Skipping line 1095793: expected 12 fields, saw 15
# Skipping line 1095811: expected 12 fields, saw 18
# Skipping line 1095823: expected 12 fields, saw 27
# Skipping line 1095829: expected 12 fields, saw 13
# Skipping line 1095840: expected 12 fields, saw 13
# Skipping line 1095892: expected 12 fields, saw 13
# Skipping line 1095894: expected 12 fields, saw 13
# Skipping line 1095902: expected 12 fields, saw 16
# Skipping line 1095908: expected 12 fields, saw 14
# Skipping line 1095919: expected 12 fields, saw 16
# Skipping line 1095938: expected 12 fields, saw 16
# Skipping line 1095958: expected 12 fields, saw 13
# Skipping line 1096012: expected 12 fields, saw 13
# Skipping line 1096017: expected 12 fields, saw 15
# Skipping line 1096027: expected 12 fields, saw 14
# Skipping line 1096028: expected 12 fields, saw 19
# Skipping line 1096045: expected 12 fields, saw 15
# Skipping line 1096046: expected 12 fields, saw 21
# Skipping line 1096084: expected 12 fields, saw 14
# Skipping line 1096104: expected 12 fields, saw 15
# Skipping line 1096139: expected 12 fields, saw 14
# Skipping line 1096150: expected 12 fields, saw 16
# Skipping line 1096154: expected 12 fields, saw 14
# Skipping line 1096182: expected 12 fields, saw 13
# Skipping line 1096216: expected 12 fields, saw 14
# Skipping line 1096229: expected 12 fields, saw 21
# Skipping line 1096239: expected 12 fields, saw 14
# Skipping line 1096251: expected 12 fields, saw 17
# Skipping line 1096270: expected 12 fields, saw 14
# Skipping line 1096285: expected 12 fields, saw 14
# Skipping line 1096294: expected 12 fields, saw 14
# Skipping line 1096324: expected 12 fields, saw 17
# Skipping line 1096337: expected 12 fields, saw 17
# Skipping line 1096353: expected 12 fields, saw 17
# Skipping line 1096354: expected 12 fields, saw 14
# Skipping line 1096355: expected 12 fields, saw 16
# Skipping line 1096367: expected 12 fields, saw 20
# Skipping line 1096371: expected 12 fields, saw 17
# Skipping line 1096384: expected 12 fields, saw 14
# Skipping line 1096403: expected 12 fields, saw 17
# Skipping line 1096435: expected 12 fields, saw 15
# Skipping line 1096447: expected 12 fields, saw 13
# Skipping line 1096448: expected 12 fields, saw 13
# Skipping line 1096455: expected 12 fields, saw 18
# Skipping line 1096473: expected 12 fields, saw 13
# Skipping line 1096505: expected 12 fields, saw 15
# Skipping line 1096512: expected 12 fields, saw 16
# Skipping line 1096516: expected 12 fields, saw 14
# Skipping line 1096546: expected 12 fields, saw 15
# Skipping line 1096549: expected 12 fields, saw 14
# Skipping line 1096569: expected 12 fields, saw 23
# Skipping line 1096580: expected 12 fields, saw 17
# Skipping line 1096599: expected 12 fields, saw 13
# Skipping line 1096623: expected 12 fields, saw 13
# Skipping line 1096629: expected 12 fields, saw 18
# Skipping line 1096641: expected 12 fields, saw 14
# Skipping line 1096645: expected 12 fields, saw 18
# Skipping line 1096716: expected 12 fields, saw 14
# Skipping line 1096719: expected 12 fields, saw 14
# Skipping line 1096720: expected 12 fields, saw 13
# Skipping line 1096721: expected 12 fields, saw 14
# Skipping line 1096722: expected 12 fields, saw 20
# Skipping line 1096725: expected 12 fields, saw 15
# Skipping line 1096731: expected 12 fields, saw 15
# Skipping line 1096737: expected 12 fields, saw 13
# Skipping line 1096752: expected 12 fields, saw 25
# Skipping line 1096753: expected 12 fields, saw 15
# Skipping line 1096759: expected 12 fields, saw 17
# Skipping line 1096790: expected 12 fields, saw 14
# Skipping line 1096794: expected 12 fields, saw 22
# Skipping line 1096829: expected 12 fields, saw 15
# Skipping line 1096844: expected 12 fields, saw 13
# Skipping line 1096874: expected 12 fields, saw 17
# Skipping line 1096878: expected 12 fields, saw 15
# Skipping line 1096913: expected 12 fields, saw 16
# Skipping line 1096967: expected 12 fields, saw 14
# Skipping line 1096990: expected 12 fields, saw 16
# Skipping line 1097119: expected 12 fields, saw 14
# Skipping line 1097122: expected 12 fields, saw 13
# Skipping line 1097151: expected 12 fields, saw 13
# Skipping line 1097173: expected 12 fields, saw 15
# Skipping line 1097226: expected 12 fields, saw 14
# Skipping line 1097246: expected 12 fields, saw 14
# Skipping line 1097257: expected 12 fields, saw 15
# Skipping line 1097283: expected 12 fields, saw 13
# Skipping line 1097284: expected 12 fields, saw 16
# Skipping line 1097289: expected 12 fields, saw 14
# Skipping line 1097330: expected 12 fields, saw 14
# Skipping line 1097331: expected 12 fields, saw 19
# Skipping line 1097367: expected 12 fields, saw 13
# Skipping line 1097374: expected 12 fields, saw 20
# Skipping line 1097382: expected 12 fields, saw 13
# Skipping line 1097385: expected 12 fields, saw 14
# Skipping line 1097395: expected 12 fields, saw 17
# Skipping line 1097421: expected 12 fields, saw 16
# Skipping line 1097424: expected 12 fields, saw 15
# Skipping line 1097430: expected 12 fields, saw 13
# Skipping line 1097447: expected 12 fields, saw 17
# Skipping line 1097449: expected 12 fields, saw 13
# Skipping line 1097463: expected 12 fields, saw 13
# Skipping line 1097487: expected 12 fields, saw 13
# Skipping line 1097553: expected 12 fields, saw 14
# Skipping line 1097571: expected 12 fields, saw 15
# Skipping line 1097584: expected 12 fields, saw 18
# Skipping line 1097585: expected 12 fields, saw 13
# Skipping line 1097593: expected 12 fields, saw 13
# Skipping line 1097602: expected 12 fields, saw 13
# Skipping line 1097614: expected 12 fields, saw 16
# Skipping line 1097618: expected 12 fields, saw 18
# Skipping line 1097627: expected 12 fields, saw 13
# Skipping line 1097758: expected 12 fields, saw 16
# Skipping line 1097763: expected 12 fields, saw 18
# Skipping line 1097770: expected 12 fields, saw 19
# Skipping line 1097829: expected 12 fields, saw 15
# Skipping line 1097831: expected 12 fields, saw 13
# Skipping line 1097858: expected 12 fields, saw 14
# Skipping line 1097860: expected 12 fields, saw 13
# Skipping line 1097862: expected 12 fields, saw 14
# Skipping line 1097865: expected 12 fields, saw 13
# Skipping line 1097898: expected 12 fields, saw 13
# Skipping line 1097937: expected 12 fields, saw 13
# Skipping line 1097956: expected 12 fields, saw 13
# Skipping line 1098030: expected 12 fields, saw 14
# Skipping line 1098070: expected 12 fields, saw 13
# Skipping line 1098086: expected 12 fields, saw 13
# Skipping line 1098094: expected 12 fields, saw 16
# Skipping line 1098097: expected 12 fields, saw 18
# Skipping line 1098100: expected 12 fields, saw 14
# Skipping line 1098121: expected 12 fields, saw 13
# Skipping line 1098122: expected 12 fields, saw 16
# Skipping line 1098132: expected 12 fields, saw 14
# Skipping line 1098179: expected 12 fields, saw 13
# Skipping line 1098180: expected 12 fields, saw 23
# Skipping line 1098183: expected 12 fields, saw 17
# Skipping line 1098193: expected 12 fields, saw 14
# Skipping line 1098210: expected 12 fields, saw 13
# Skipping line 1098223: expected 12 fields, saw 13
# Skipping line 1098224: expected 12 fields, saw 13
# Skipping line 1098226: expected 12 fields, saw 17
# Skipping line 1098227: expected 12 fields, saw 13
# Skipping line 1098231: expected 12 fields, saw 15
# Skipping line 1098233: expected 12 fields, saw 16
# Skipping line 1098245: expected 12 fields, saw 14
# Skipping line 1098302: expected 12 fields, saw 15
# Skipping line 1098328: expected 12 fields, saw 15
# Skipping line 1098340: expected 12 fields, saw 15
# Skipping line 1098450: expected 12 fields, saw 13
# Skipping line 1098461: expected 12 fields, saw 14
# Skipping line 1098529: expected 12 fields, saw 16
# Skipping line 1098548: expected 12 fields, saw 18
# Skipping line 1098562: expected 12 fields, saw 14
# Skipping line 1098571: expected 12 fields, saw 13
# Skipping line 1098616: expected 12 fields, saw 15
# Skipping line 1098619: expected 12 fields, saw 14
# Skipping line 1098622: expected 12 fields, saw 13
# Skipping line 1098629: expected 12 fields, saw 15
# Skipping line 1098638: expected 12 fields, saw 13
# Skipping line 1098643: expected 12 fields, saw 13
# Skipping line 1098648: expected 12 fields, saw 22
# Skipping line 1098662: expected 12 fields, saw 13
# Skipping line 1098711: expected 12 fields, saw 14
# Skipping line 1098721: expected 12 fields, saw 14
# Skipping line 1098750: expected 12 fields, saw 16
# Skipping line 1098756: expected 12 fields, saw 13
# Skipping line 1098765: expected 12 fields, saw 15
# Skipping line 1098782: expected 12 fields, saw 13
# Skipping line 1098794: expected 12 fields, saw 14
# Skipping line 1098798: expected 12 fields, saw 13
# Skipping line 1098866: expected 12 fields, saw 14
# Skipping line 1098869: expected 12 fields, saw 14
# Skipping line 1098894: expected 12 fields, saw 13
# Skipping line 1098933: expected 12 fields, saw 17
# Skipping line 1098939: expected 12 fields, saw 14
# Skipping line 1098947: expected 12 fields, saw 14
# Skipping line 1098956: expected 12 fields, saw 15
# Skipping line 1098994: expected 12 fields, saw 16
# Skipping line 1098999: expected 12 fields, saw 14
# Skipping line 1099022: expected 12 fields, saw 16
# Skipping line 1099024: expected 12 fields, saw 14
# Skipping line 1099026: expected 12 fields, saw 21
# Skipping line 1099037: expected 12 fields, saw 16
# Skipping line 1099040: expected 12 fields, saw 15
# Skipping line 1099041: expected 12 fields, saw 18
# Skipping line 1099052: expected 12 fields, saw 13
# Skipping line 1099057: expected 12 fields, saw 15
# Skipping line 1099058: expected 12 fields, saw 13
# Skipping line 1099059: expected 12 fields, saw 20
# Skipping line 1099099: expected 12 fields, saw 16
# Skipping line 1099103: expected 12 fields, saw 14
# Skipping line 1099127: expected 12 fields, saw 23
# Skipping line 1099259: expected 12 fields, saw 16
# Skipping line 1099335: expected 12 fields, saw 15
# Skipping line 1099385: expected 12 fields, saw 18
# Skipping line 1099416: expected 12 fields, saw 14
# Skipping line 1099430: expected 12 fields, saw 14
# Skipping line 1099448: expected 12 fields, saw 13
# Skipping line 1099463: expected 12 fields, saw 16
# Skipping line 1099475: expected 12 fields, saw 16
# Skipping line 1099523: expected 12 fields, saw 13
# Skipping line 1099526: expected 12 fields, saw 13
# Skipping line 1099531: expected 12 fields, saw 20
# Skipping line 1099560: expected 12 fields, saw 18
# Skipping line 1099586: expected 12 fields, saw 14
# Skipping line 1099588: expected 12 fields, saw 14
# Skipping line 1099599: expected 12 fields, saw 15
# Skipping line 1099609: expected 12 fields, saw 16
# Skipping line 1099616: expected 12 fields, saw 25
# Skipping line 1099618: expected 12 fields, saw 13
# Skipping line 1099638: expected 12 fields, saw 13
# Skipping line 1099641: expected 12 fields, saw 13
# Skipping line 1099657: expected 12 fields, saw 14
# Skipping line 1099765: expected 12 fields, saw 13
# Skipping line 1099778: expected 12 fields, saw 13
# Skipping line 1099783: expected 12 fields, saw 13
# Skipping line 1099812: expected 12 fields, saw 18
# Skipping line 1099861: expected 12 fields, saw 15
# Skipping line 1099867: expected 12 fields, saw 16
# Skipping line 1099890: expected 12 fields, saw 15
# Skipping line 1099945: expected 12 fields, saw 13
# Skipping line 1099995: expected 12 fields, saw 13
# Skipping line 1100004: expected 12 fields, saw 13
# Skipping line 1100030: expected 12 fields, saw 13
# Skipping line 1100032: expected 12 fields, saw 13
# Skipping line 1100044: expected 12 fields, saw 17
# Skipping line 1100067: expected 12 fields, saw 13
# Skipping line 1100083: expected 12 fields, saw 16
# Skipping line 1100097: expected 12 fields, saw 28
# Skipping line 1100100: expected 12 fields, saw 13
# Skipping line 1100104: expected 12 fields, saw 23
# Skipping line 1100140: expected 12 fields, saw 14
# Skipping line 1100147: expected 12 fields, saw 13
# Skipping line 1100157: expected 12 fields, saw 19
# Skipping line 1100190: expected 12 fields, saw 14
# Skipping line 1100203: expected 12 fields, saw 13
# Skipping line 1100230: expected 12 fields, saw 16
# Skipping line 1100311: expected 12 fields, saw 19
# Skipping line 1100321: expected 12 fields, saw 18
# Skipping line 1100326: expected 12 fields, saw 17
# Skipping line 1100329: expected 12 fields, saw 14
# Skipping line 1100344: expected 12 fields, saw 17
# Skipping line 1100351: expected 12 fields, saw 19
# Skipping line 1100366: expected 12 fields, saw 13
# Skipping line 1100378: expected 12 fields, saw 15
# Skipping line 1100388: expected 12 fields, saw 13
# Skipping line 1100398: expected 12 fields, saw 17
# Skipping line 1100401: expected 12 fields, saw 13
# Skipping line 1100411: expected 12 fields, saw 14
# Skipping line 1100423: expected 12 fields, saw 13
# Skipping line 1100453: expected 12 fields, saw 14
# Skipping line 1100494: expected 12 fields, saw 14
# Skipping line 1100499: expected 12 fields, saw 13
# Skipping line 1100533: expected 12 fields, saw 13
# Skipping line 1100578: expected 12 fields, saw 18
# Skipping line 1100604: expected 12 fields, saw 17
# Skipping line 1100612: expected 12 fields, saw 14
# Skipping line 1100614: expected 12 fields, saw 14
# Skipping line 1100635: expected 12 fields, saw 13
# Skipping line 1100647: expected 12 fields, saw 13
# Skipping line 1100662: expected 12 fields, saw 13
# Skipping line 1100680: expected 12 fields, saw 13
# Skipping line 1100688: expected 12 fields, saw 13
# Skipping line 1100693: expected 12 fields, saw 13
# Skipping line 1100707: expected 12 fields, saw 13
# Skipping line 1100713: expected 12 fields, saw 13
# Skipping line 1100716: expected 12 fields, saw 16
# Skipping line 1100731: expected 12 fields, saw 13
# Skipping line 1100751: expected 12 fields, saw 15
# Skipping line 1100755: expected 12 fields, saw 14
# Skipping line 1100785: expected 12 fields, saw 16
# Skipping line 1100789: expected 12 fields, saw 18
# Skipping line 1100794: expected 12 fields, saw 15
# Skipping line 1100807: expected 12 fields, saw 13
# Skipping line 1100809: expected 12 fields, saw 14
# Skipping line 1100816: expected 12 fields, saw 13
# Skipping line 1100821: expected 12 fields, saw 13
# Skipping line 1100832: expected 12 fields, saw 15
# Skipping line 1100845: expected 12 fields, saw 13
# Skipping line 1100880: expected 12 fields, saw 15
# Skipping line 1100904: expected 12 fields, saw 17
# Skipping line 1100917: expected 12 fields, saw 14
# Skipping line 1100936: expected 12 fields, saw 14
# Skipping line 1100953: expected 12 fields, saw 13
# Skipping line 1100973: expected 12 fields, saw 14
# Skipping line 1101015: expected 12 fields, saw 17
# Skipping line 1101019: expected 12 fields, saw 14
# Skipping line 1101039: expected 12 fields, saw 13
# Skipping line 1101057: expected 12 fields, saw 16
# Skipping line 1101070: expected 12 fields, saw 16
# Skipping line 1101089: expected 12 fields, saw 15
# Skipping line 1101095: expected 12 fields, saw 14
# Skipping line 1101098: expected 12 fields, saw 14
# Skipping line 1101117: expected 12 fields, saw 13
# Skipping line 1101126: expected 12 fields, saw 13
# Skipping line 1101166: expected 12 fields, saw 24
# Skipping line 1101193: expected 12 fields, saw 13
# Skipping line 1101199: expected 12 fields, saw 15
# Skipping line 1101209: expected 12 fields, saw 18
# Skipping line 1101228: expected 12 fields, saw 15
# Skipping line 1101229: expected 12 fields, saw 15
# Skipping line 1101234: expected 12 fields, saw 13
# Skipping line 1101243: expected 12 fields, saw 13
# Skipping line 1101258: expected 12 fields, saw 15
# Skipping line 1101265: expected 12 fields, saw 15
# Skipping line 1101283: expected 12 fields, saw 14
# Skipping line 1101293: expected 12 fields, saw 15
# Skipping line 1101312: expected 12 fields, saw 16
# Skipping line 1101317: expected 12 fields, saw 16
# Skipping line 1101388: expected 12 fields, saw 15
# Skipping line 1101395: expected 12 fields, saw 13
# Skipping line 1101396: expected 12 fields, saw 15
# Skipping line 1101415: expected 12 fields, saw 18
# Skipping line 1101431: expected 12 fields, saw 31
# Skipping line 1101432: expected 12 fields, saw 16
# Skipping line 1101447: expected 12 fields, saw 13
# Skipping line 1101449: expected 12 fields, saw 14
# Skipping line 1101459: expected 12 fields, saw 19
# Skipping line 1101460: expected 12 fields, saw 14
# Skipping line 1101461: expected 12 fields, saw 16
# Skipping line 1101472: expected 12 fields, saw 13
# Skipping line 1101493: expected 12 fields, saw 15
# Skipping line 1101510: expected 12 fields, saw 14
# Skipping line 1101512: expected 12 fields, saw 13
# Skipping line 1101529: expected 12 fields, saw 13
# Skipping line 1101535: expected 12 fields, saw 17
# Skipping line 1101541: expected 12 fields, saw 14
# Skipping line 1101564: expected 12 fields, saw 14
# Skipping line 1101575: expected 12 fields, saw 13
# Skipping line 1101584: expected 12 fields, saw 16
# Skipping line 1101603: expected 12 fields, saw 19
# Skipping line 1101605: expected 12 fields, saw 14
# Skipping line 1101608: expected 12 fields, saw 35
# Skipping line 1101623: expected 12 fields, saw 15
# Skipping line 1101678: expected 12 fields, saw 26
# Skipping line 1101706: expected 12 fields, saw 15
# Skipping line 1101715: expected 12 fields, saw 16
# Skipping line 1101720: expected 12 fields, saw 18
# Skipping line 1101738: expected 12 fields, saw 15
# Skipping line 1101773: expected 12 fields, saw 14
# Skipping line 1101776: expected 12 fields, saw 21
# Skipping line 1101782: expected 12 fields, saw 13
# Skipping line 1101788: expected 12 fields, saw 13
# Skipping line 1101812: expected 12 fields, saw 13
# Skipping line 1101824: expected 12 fields, saw 20
# Skipping line 1101856: expected 12 fields, saw 13
# Skipping line 1101882: expected 12 fields, saw 16
# Skipping line 1101977: expected 12 fields, saw 15
# Skipping line 1101992: expected 12 fields, saw 15
# Skipping line 1102026: expected 12 fields, saw 19
# Skipping line 1102049: expected 12 fields, saw 14
# Skipping line 1102050: expected 12 fields, saw 15
# Skipping line 1102065: expected 12 fields, saw 13
# Skipping line 1102073: expected 12 fields, saw 17
# Skipping line 1102124: expected 12 fields, saw 16
# Skipping line 1102161: expected 12 fields, saw 17
# Skipping line 1102166: expected 12 fields, saw 14
# Skipping line 1102181: expected 12 fields, saw 13
# Skipping line 1102195: expected 12 fields, saw 16
# Skipping line 1102210: expected 12 fields, saw 15
# Skipping line 1102216: expected 12 fields, saw 16
# Skipping line 1102231: expected 12 fields, saw 13
# Skipping line 1102250: expected 12 fields, saw 14
# Skipping line 1102255: expected 12 fields, saw 15
# Skipping line 1102259: expected 12 fields, saw 13
# Skipping line 1102273: expected 12 fields, saw 13
# Skipping line 1102285: expected 12 fields, saw 14
# Skipping line 1102298: expected 12 fields, saw 13
# Skipping line 1102305: expected 12 fields, saw 15
# Skipping line 1102307: expected 12 fields, saw 13
# Skipping line 1102316: expected 12 fields, saw 13
# Skipping line 1102327: expected 12 fields, saw 15
# Skipping line 1102392: expected 12 fields, saw 21
# Skipping line 1102422: expected 12 fields, saw 20
# Skipping line 1102435: expected 12 fields, saw 13
# Skipping line 1102455: expected 12 fields, saw 13
# Skipping line 1102465: expected 12 fields, saw 15
# Skipping line 1102478: expected 12 fields, saw 13
# Skipping line 1102484: expected 12 fields, saw 13
# Skipping line 1102512: expected 12 fields, saw 13
# Skipping line 1102519: expected 12 fields, saw 16
# Skipping line 1102521: expected 12 fields, saw 13
# Skipping line 1102556: expected 12 fields, saw 14
# Skipping line 1102658: expected 12 fields, saw 13
# Skipping line 1102684: expected 12 fields, saw 16
# Skipping line 1102729: expected 12 fields, saw 13
# Skipping line 1102766: expected 12 fields, saw 13
# Skipping line 1102774: expected 12 fields, saw 21
# Skipping line 1102776: expected 12 fields, saw 22
# Skipping line 1102790: expected 12 fields, saw 17
# Skipping line 1102791: expected 12 fields, saw 14
# Skipping line 1102794: expected 12 fields, saw 15
# Skipping line 1102810: expected 12 fields, saw 13
# Skipping line 1102828: expected 12 fields, saw 15
# Skipping line 1102841: expected 12 fields, saw 19
# Skipping line 1102859: expected 12 fields, saw 13
# Skipping line 1102913: expected 12 fields, saw 17
# Skipping line 1102924: expected 12 fields, saw 15
# Skipping line 1102931: expected 12 fields, saw 14
# Skipping line 1102936: expected 12 fields, saw 13
# Skipping line 1102938: expected 12 fields, saw 13
# Skipping line 1102942: expected 12 fields, saw 13
# Skipping line 1102943: expected 12 fields, saw 14
# Skipping line 1102956: expected 12 fields, saw 13
# Skipping line 1102994: expected 12 fields, saw 19
# Skipping line 1103014: expected 12 fields, saw 13
# Skipping line 1103025: expected 12 fields, saw 13
# Skipping line 1103066: expected 12 fields, saw 14
# Skipping line 1103106: expected 12 fields, saw 16
# Skipping line 1103107: expected 12 fields, saw 15
# Skipping line 1103131: expected 12 fields, saw 14
# Skipping line 1103168: expected 12 fields, saw 16
# Skipping line 1103174: expected 12 fields, saw 14
# Skipping line 1103185: expected 12 fields, saw 13
# Skipping line 1103187: expected 12 fields, saw 14
# Skipping line 1103205: expected 12 fields, saw 17
# Skipping line 1103213: expected 12 fields, saw 13
# Skipping line 1103216: expected 12 fields, saw 17
# Skipping line 1103219: expected 12 fields, saw 14
# Skipping line 1103225: expected 12 fields, saw 14
# Skipping line 1103242: expected 12 fields, saw 20
# Skipping line 1103256: expected 12 fields, saw 15
# Skipping line 1103272: expected 12 fields, saw 14
# Skipping line 1103284: expected 12 fields, saw 18
# Skipping line 1103318: expected 12 fields, saw 14
# Skipping line 1103331: expected 12 fields, saw 17
# Skipping line 1103335: expected 12 fields, saw 15
# Skipping line 1103385: expected 12 fields, saw 15
# Skipping line 1103387: expected 12 fields, saw 16
# Skipping line 1103418: expected 12 fields, saw 14
# Skipping line 1103422: expected 12 fields, saw 16
# Skipping line 1103427: expected 12 fields, saw 14
# Skipping line 1103451: expected 12 fields, saw 13
# Skipping line 1103487: expected 12 fields, saw 13
# Skipping line 1103519: expected 12 fields, saw 17
# Skipping line 1103520: expected 12 fields, saw 14
# Skipping line 1103526: expected 12 fields, saw 16
# Skipping line 1103549: expected 12 fields, saw 17
# Skipping line 1103555: expected 12 fields, saw 14
# Skipping line 1103575: expected 12 fields, saw 14
# Skipping line 1103577: expected 12 fields, saw 13
# Skipping line 1103579: expected 12 fields, saw 13
# Skipping line 1103581: expected 12 fields, saw 13
# Skipping line 1103612: expected 12 fields, saw 14
# Skipping line 1103614: expected 12 fields, saw 14
# Skipping line 1103626: expected 12 fields, saw 14
# Skipping line 1103658: expected 12 fields, saw 16
# Skipping line 1103678: expected 12 fields, saw 15
# Skipping line 1103708: expected 12 fields, saw 13
# Skipping line 1103765: expected 12 fields, saw 13
# Skipping line 1103769: expected 12 fields, saw 15
# Skipping line 1103806: expected 12 fields, saw 18
# Skipping line 1103838: expected 12 fields, saw 15
# Skipping line 1103860: expected 12 fields, saw 16
# Skipping line 1103878: expected 12 fields, saw 16
# Skipping line 1103885: expected 12 fields, saw 13
# Skipping line 1103894: expected 12 fields, saw 16
# Skipping line 1103913: expected 12 fields, saw 14
# Skipping line 1103916: expected 12 fields, saw 18
# Skipping line 1103924: expected 12 fields, saw 15
# Skipping line 1103928: expected 12 fields, saw 16
# Skipping line 1103929: expected 12 fields, saw 14
# Skipping line 1103937: expected 12 fields, saw 13
# Skipping line 1103960: expected 12 fields, saw 14
# Skipping line 1103961: expected 12 fields, saw 19
# Skipping line 1104013: expected 12 fields, saw 14
# Skipping line 1104039: expected 12 fields, saw 13
# Skipping line 1104061: expected 12 fields, saw 13
# Skipping line 1104070: expected 12 fields, saw 13
# Skipping line 1104076: expected 12 fields, saw 13
# Skipping line 1104096: expected 12 fields, saw 18
# Skipping line 1104106: expected 12 fields, saw 14
# Skipping line 1104107: expected 12 fields, saw 13
# Skipping line 1104112: expected 12 fields, saw 15
# Skipping line 1104133: expected 12 fields, saw 15
# Skipping line 1104162: expected 12 fields, saw 17
# Skipping line 1104165: expected 12 fields, saw 19
# Skipping line 1104169: expected 12 fields, saw 13
# Skipping line 1104170: expected 12 fields, saw 14
# Skipping line 1104182: expected 12 fields, saw 14
# Skipping line 1104192: expected 12 fields, saw 22
# Skipping line 1104198: expected 12 fields, saw 16
# Skipping line 1104203: expected 12 fields, saw 16
# Skipping line 1104216: expected 12 fields, saw 16
# Skipping line 1104227: expected 12 fields, saw 16
# Skipping line 1104233: expected 12 fields, saw 13
# Skipping line 1104249: expected 12 fields, saw 15
# Skipping line 1104252: expected 12 fields, saw 14
# Skipping line 1104265: expected 12 fields, saw 17
# Skipping line 1104275: expected 12 fields, saw 19
# Skipping line 1104321: expected 12 fields, saw 17
# Skipping line 1104353: expected 12 fields, saw 14
# Skipping line 1104379: expected 12 fields, saw 13
# Skipping line 1104380: expected 12 fields, saw 13
# Skipping line 1104410: expected 12 fields, saw 14
# Skipping line 1104413: expected 12 fields, saw 13
# Skipping line 1104429: expected 12 fields, saw 15
# Skipping line 1104435: expected 12 fields, saw 19
# Skipping line 1104439: expected 12 fields, saw 13
# Skipping line 1104493: expected 12 fields, saw 15
# Skipping line 1104540: expected 12 fields, saw 14
# Skipping line 1104545: expected 12 fields, saw 16
# Skipping line 1104575: expected 12 fields, saw 17
# Skipping line 1104581: expected 12 fields, saw 15
# Skipping line 1104602: expected 12 fields, saw 14
# Skipping line 1104612: expected 12 fields, saw 17
# Skipping line 1104641: expected 12 fields, saw 14
# Skipping line 1104650: expected 12 fields, saw 23
# Skipping line 1104684: expected 12 fields, saw 14
# Skipping line 1104694: expected 12 fields, saw 13
# Skipping line 1104753: expected 12 fields, saw 18
# Skipping line 1104754: expected 12 fields, saw 13
# Skipping line 1104761: expected 12 fields, saw 15
# Skipping line 1104764: expected 12 fields, saw 14
# Skipping line 1104773: expected 12 fields, saw 13
# Skipping line 1104808: expected 12 fields, saw 16
# Skipping line 1104815: expected 12 fields, saw 19
# Skipping line 1104837: expected 12 fields, saw 15
# Skipping line 1104881: expected 12 fields, saw 13
# Skipping line 1104911: expected 12 fields, saw 14
# Skipping line 1104922: expected 12 fields, saw 13
# Skipping line 1104929: expected 12 fields, saw 16
# Skipping line 1104938: expected 12 fields, saw 15
# Skipping line 1104943: expected 12 fields, saw 15
# Skipping line 1104946: expected 12 fields, saw 13
# Skipping line 1104948: expected 12 fields, saw 14
# Skipping line 1104952: expected 12 fields, saw 13
# Skipping line 1104966: expected 12 fields, saw 13
# Skipping line 1104975: expected 12 fields, saw 13
# Skipping line 1104976: expected 12 fields, saw 16
# Skipping line 1104978: expected 12 fields, saw 14
# Skipping line 1104990: expected 12 fields, saw 14
# Skipping line 1104995: expected 12 fields, saw 13
# Skipping line 1105024: expected 12 fields, saw 16
# Skipping line 1105029: expected 12 fields, saw 13
# Skipping line 1105059: expected 12 fields, saw 14
# Skipping line 1105073: expected 12 fields, saw 23
# Skipping line 1105085: expected 12 fields, saw 14
# Skipping line 1105095: expected 12 fields, saw 15
# Skipping line 1105101: expected 12 fields, saw 13
# Skipping line 1105116: expected 12 fields, saw 14
# Skipping line 1105122: expected 12 fields, saw 16
# Skipping line 1105127: expected 12 fields, saw 17
# Skipping line 1105131: expected 12 fields, saw 13
# Skipping line 1105147: expected 12 fields, saw 13
# Skipping line 1105155: expected 12 fields, saw 14
# Skipping line 1105173: expected 12 fields, saw 13
# Skipping line 1105208: expected 12 fields, saw 14
# Skipping line 1105212: expected 12 fields, saw 14
# Skipping line 1105213: expected 12 fields, saw 20
# Skipping line 1105220: expected 12 fields, saw 15
# Skipping line 1105238: expected 12 fields, saw 18
# Skipping line 1105277: expected 12 fields, saw 15
# Skipping line 1105302: expected 12 fields, saw 14
# Skipping line 1105311: expected 12 fields, saw 17
# Skipping line 1105354: expected 12 fields, saw 21
# Skipping line 1105359: expected 12 fields, saw 19
# Skipping line 1105379: expected 12 fields, saw 14
# Skipping line 1105414: expected 12 fields, saw 15
# Skipping line 1105420: expected 12 fields, saw 15
# Skipping line 1105454: expected 12 fields, saw 19
# Skipping line 1105495: expected 12 fields, saw 15
# Skipping line 1105543: expected 12 fields, saw 20
# Skipping line 1105574: expected 12 fields, saw 13
# Skipping line 1105580: expected 12 fields, saw 15
# Skipping line 1105595: expected 12 fields, saw 20
# Skipping line 1105616: expected 12 fields, saw 13
# Skipping line 1105639: expected 12 fields, saw 23
# Skipping line 1105640: expected 12 fields, saw 13
# Skipping line 1105660: expected 12 fields, saw 13
# Skipping line 1105662: expected 12 fields, saw 13
# Skipping line 1105710: expected 12 fields, saw 17
# Skipping line 1105720: expected 12 fields, saw 16
# Skipping line 1105742: expected 12 fields, saw 14
# Skipping line 1105764: expected 12 fields, saw 13
# Skipping line 1105775: expected 12 fields, saw 13
# Skipping line 1105816: expected 12 fields, saw 13
# Skipping line 1105831: expected 12 fields, saw 15
# Skipping line 1105833: expected 12 fields, saw 13
# Skipping line 1105861: expected 12 fields, saw 15
# Skipping line 1105884: expected 12 fields, saw 14
# Skipping line 1105914: expected 12 fields, saw 17
# Skipping line 1105932: expected 12 fields, saw 15
# Skipping line 1105964: expected 12 fields, saw 16
# Skipping line 1105998: expected 12 fields, saw 15
# Skipping line 1106002: expected 12 fields, saw 14
# Skipping line 1106005: expected 12 fields, saw 13
# Skipping line 1106018: expected 12 fields, saw 13
# Skipping line 1106029: expected 12 fields, saw 14
# Skipping line 1106044: expected 12 fields, saw 15
# Skipping line 1106045: expected 12 fields, saw 16
# Skipping line 1106049: expected 12 fields, saw 13
# Skipping line 1106126: expected 12 fields, saw 22
# Skipping line 1106171: expected 12 fields, saw 16
# Skipping line 1106216: expected 12 fields, saw 14
# Skipping line 1106220: expected 12 fields, saw 13
# Skipping line 1106227: expected 12 fields, saw 18
# Skipping line 1106229: expected 12 fields, saw 13
# Skipping line 1106236: expected 12 fields, saw 13
# Skipping line 1106254: expected 12 fields, saw 13
# Skipping line 1106260: expected 12 fields, saw 14
# Skipping line 1106270: expected 12 fields, saw 18
# Skipping line 1106271: expected 12 fields, saw 13
# Skipping line 1106277: expected 12 fields, saw 17
# Skipping line 1106284: expected 12 fields, saw 24
# Skipping line 1106285: expected 12 fields, saw 16
# Skipping line 1106292: expected 12 fields, saw 14
# Skipping line 1106305: expected 12 fields, saw 14
# Skipping line 1106306: expected 12 fields, saw 17
# Skipping line 1106313: expected 12 fields, saw 13
# Skipping line 1106314: expected 12 fields, saw 13
# Skipping line 1106316: expected 12 fields, saw 15
# Skipping line 1106318: expected 12 fields, saw 19
# Skipping line 1106319: expected 12 fields, saw 19
# Skipping line 1106339: expected 12 fields, saw 20
# Skipping line 1106350: expected 12 fields, saw 13
# Skipping line 1106374: expected 12 fields, saw 14
# Skipping line 1106387: expected 12 fields, saw 14
# Skipping line 1106395: expected 12 fields, saw 13
# ...
# Skipping line 1477815: expected 12 fields, saw 13
# Skipping line 1477816: expected 12 fields, saw 20
# Skipping line 1477832: expected 12 fields, saw 13
# Skipping line 1477853: expected 12 fields, saw 14
# Skipping line 1477858: expected 12 fields, saw 15
# Skipping line 1477886: expected 12 fields, saw 13
# Skipping line 1477889: expected 12 fields, saw 15
# Skipping line 1477924: expected 12 fields, saw 14
# Skipping line 1477936: expected 12 fields, saw 13
# Skipping line 1477970: expected 12 fields, saw 13
# Skipping line 1477972: expected 12 fields, saw 15
# Skipping line 1477997: expected 12 fields, saw 13
# Skipping line 1478003: expected 12 fields, saw 13
# Skipping line 1478008: expected 12 fields, saw 14
# Skipping line 1478012: expected 12 fields, saw 19
# Skipping line 1478024: expected 12 fields, saw 13
# Skipping line 1478055: expected 12 fields, saw 14
# Skipping line 1478057: expected 12 fields, saw 13
# Skipping line 1478090: expected 12 fields, saw 16
# Skipping line 1478093: expected 12 fields, saw 13
# Skipping line 1478098: expected 12 fields, saw 18
# Skipping line 1478134: expected 12 fields, saw 13
# Skipping line 1478135: expected 12 fields, saw 15
# Skipping line 1478142: expected 12 fields, saw 15
# Skipping line 1478150: expected 12 fields, saw 14
# Skipping line 1478207: expected 12 fields, saw 17
# Skipping line 1478244: expected 12 fields, saw 15
# Skipping line 1478246: expected 12 fields, saw 14
# Skipping line 1478257: expected 12 fields, saw 13
# Skipping line 1478266: expected 12 fields, saw 13
# Skipping line 1478274: expected 12 fields, saw 13
# Skipping line 1478285: expected 12 fields, saw 22
# Skipping line 1478296: expected 12 fields, saw 26
# Skipping line 1478307: expected 12 fields, saw 15
# Skipping line 1478309: expected 12 fields, saw 18
# Skipping line 1478330: expected 12 fields, saw 13
# Skipping line 1478380: expected 12 fields, saw 21
# Skipping line 1478385: expected 12 fields, saw 20
# Skipping line 1478390: expected 12 fields, saw 13
# Skipping line 1478391: expected 12 fields, saw 15
# Skipping line 1478401: expected 12 fields, saw 14
# Skipping line 1478407: expected 12 fields, saw 13
# Skipping line 1478411: expected 12 fields, saw 14
# Skipping line 1478435: expected 12 fields, saw 14
# Skipping line 1478470: expected 12 fields, saw 13
# Skipping line 1478482: expected 12 fields, saw 13
# Skipping line 1478485: expected 12 fields, saw 14
# Skipping line 1478488: expected 12 fields, saw 15
# Skipping line 1478496: expected 12 fields, saw 13
# Skipping line 1478524: expected 12 fields, saw 13
# Skipping line 1478551: expected 12 fields, saw 17
# Skipping line 1478561: expected 12 fields, saw 15
# Skipping line 1478580: expected 12 fields, saw 15
# Skipping line 1478606: expected 12 fields, saw 13
# Skipping line 1478613: expected 12 fields, saw 13
# Skipping line 1478617: expected 12 fields, saw 20
# Skipping line 1478621: expected 12 fields, saw 17
# Skipping line 1478634: expected 12 fields, saw 14
# Skipping line 1478657: expected 12 fields, saw 15
# Skipping line 1478687: expected 12 fields, saw 18
# Skipping line 1478697: expected 12 fields, saw 16
# Skipping line 1478702: expected 12 fields, saw 18
# Skipping line 1478710: expected 12 fields, saw 13
# Skipping line 1478714: expected 12 fields, saw 16
# Skipping line 1478716: expected 12 fields, saw 14
# Skipping line 1478790: expected 12 fields, saw 19
# Skipping line 1478794: expected 12 fields, saw 16
# Skipping line 1478806: expected 12 fields, saw 15
# Skipping line 1478817: expected 12 fields, saw 14
# Skipping line 1478837: expected 12 fields, saw 13
# Skipping line 1478850: expected 12 fields, saw 16
# Skipping line 1478855: expected 12 fields, saw 14
# Skipping line 1478859: expected 12 fields, saw 14
# Skipping line 1478888: expected 12 fields, saw 17
# Skipping line 1478899: expected 12 fields, saw 14
# Skipping line 1478925: expected 12 fields, saw 15
# Skipping line 1478926: expected 12 fields, saw 13
# Skipping line 1478934: expected 12 fields, saw 14
# Skipping line 1478983: expected 12 fields, saw 15
# Skipping line 1478987: expected 12 fields, saw 15
# Skipping line 1478997: expected 12 fields, saw 13
# Skipping line 1479001: expected 12 fields, saw 13
# Skipping line 1479005: expected 12 fields, saw 14
# Skipping line 1479006: expected 12 fields, saw 17
# Skipping line 1479051: expected 12 fields, saw 13
# Skipping line 1479063: expected 12 fields, saw 15
# Skipping line 1479084: expected 12 fields, saw 16
# Skipping line 1479087: expected 12 fields, saw 14
# Skipping line 1479089: expected 12 fields, saw 17
# Skipping line 1479097: expected 12 fields, saw 13
# Skipping line 1479099: expected 12 fields, saw 13
# Skipping line 1479108: expected 12 fields, saw 13
# Skipping line 1479111: expected 12 fields, saw 14
# Skipping line 1479126: expected 12 fields, saw 14
# Skipping line 1479174: expected 12 fields, saw 14
# Skipping line 1479182: expected 12 fields, saw 17
# Skipping line 1479186: expected 12 fields, saw 14
# Skipping line 1479200: expected 12 fields, saw 17
# Skipping line 1479253: expected 12 fields, saw 13
# Skipping line 1479265: expected 12 fields, saw 19
# Skipping line 1479285: expected 12 fields, saw 24
# Skipping line 1479300: expected 12 fields, saw 15
# Skipping line 1479303: expected 12 fields, saw 16
# Skipping line 1479304: expected 12 fields, saw 13
# Skipping line 1479306: expected 12 fields, saw 14
# Skipping line 1479324: expected 12 fields, saw 14
# Skipping line 1479326: expected 12 fields, saw 15
# Skipping line 1479334: expected 12 fields, saw 13
# Skipping line 1479337: expected 12 fields, saw 19
# Skipping line 1479338: expected 12 fields, saw 14
# Skipping line 1479345: expected 12 fields, saw 14
# Skipping line 1479367: expected 12 fields, saw 13
# Skipping line 1479370: expected 12 fields, saw 13
# Skipping line 1479418: expected 12 fields, saw 13
# Skipping line 1479442: expected 12 fields, saw 17
# Skipping line 1479444: expected 12 fields, saw 17
# Skipping line 1479456: expected 12 fields, saw 17
# Skipping line 1479469: expected 12 fields, saw 13
# Skipping line 1479487: expected 12 fields, saw 14
# Skipping line 1479493: expected 12 fields, saw 13
# Skipping line 1479523: expected 12 fields, saw 21
# Skipping line 1479527: expected 12 fields, saw 21
# Skipping line 1479551: expected 12 fields, saw 16
# Skipping line 1479554: expected 12 fields, saw 16
# Skipping line 1479575: expected 12 fields, saw 14
# Skipping line 1479589: expected 12 fields, saw 24
# Skipping line 1479604: expected 12 fields, saw 16
# Skipping line 1479612: expected 12 fields, saw 14
# Skipping line 1479615: expected 12 fields, saw 16
# Skipping line 1479618: expected 12 fields, saw 13
# Skipping line 1479621: expected 12 fields, saw 14
# Skipping line 1479634: expected 12 fields, saw 16
# Skipping line 1479650: expected 12 fields, saw 13
# Skipping line 1479663: expected 12 fields, saw 13
# Skipping line 1479670: expected 12 fields, saw 15
# Skipping line 1479683: expected 12 fields, saw 14
# Skipping line 1479684: expected 12 fields, saw 17
# Skipping line 1479691: expected 12 fields, saw 15
# Skipping line 1479725: expected 12 fields, saw 13
# Skipping line 1479746: expected 12 fields, saw 21
# Skipping line 1479763: expected 12 fields, saw 13
# Skipping line 1479776: expected 12 fields, saw 13
# Skipping line 1479783: expected 12 fields, saw 13
# Skipping line 1479787: expected 12 fields, saw 13
# Skipping line 1479791: expected 12 fields, saw 19
# Skipping line 1479831: expected 12 fields, saw 14
# Skipping line 1479837: expected 12 fields, saw 13
# Skipping line 1479844: expected 12 fields, saw 17
# Skipping line 1479856: expected 12 fields, saw 13
# Skipping line 1479862: expected 12 fields, saw 16
# Skipping line 1479876: expected 12 fields, saw 17
# Skipping line 1479909: expected 12 fields, saw 14
# Skipping line 1479912: expected 12 fields, saw 13
# Skipping line 1479942: expected 12 fields, saw 14
# Skipping line 1479948: expected 12 fields, saw 13
# Skipping line 1479949: expected 12 fields, saw 22
# Skipping line 1479955: expected 12 fields, saw 30
# Skipping line 1479957: expected 12 fields, saw 15
# Skipping line 1479963: expected 12 fields, saw 13
# Skipping line 1479973: expected 12 fields, saw 15
# Skipping line 1480042: expected 12 fields, saw 13
# Skipping line 1480063: expected 12 fields, saw 16
# Skipping line 1480073: expected 12 fields, saw 15
# Skipping line 1480074: expected 12 fields, saw 20
# Skipping line 1480104: expected 12 fields, saw 14
# Skipping line 1480112: expected 12 fields, saw 18
# Skipping line 1480159: expected 12 fields, saw 17
# Skipping line 1480172: expected 12 fields, saw 14
# Skipping line 1480187: expected 12 fields, saw 13
# Skipping line 1480190: expected 12 fields, saw 17
# Skipping line 1480226: expected 12 fields, saw 18
# Skipping line 1480245: expected 12 fields, saw 15
# Skipping line 1480291: expected 12 fields, saw 17
# Skipping line 1480307: expected 12 fields, saw 13
# Skipping line 1480315: expected 12 fields, saw 13
# Skipping line 1480318: expected 12 fields, saw 14
# Skipping line 1480327: expected 12 fields, saw 16
# Skipping line 1480334: expected 12 fields, saw 15
# Skipping line 1480342: expected 12 fields, saw 13
# Skipping line 1480352: expected 12 fields, saw 15
# Skipping line 1480378: expected 12 fields, saw 17
# Skipping line 1480391: expected 12 fields, saw 15
# Skipping line 1480437: expected 12 fields, saw 15
# Skipping line 1480448: expected 12 fields, saw 13
# Skipping line 1480449: expected 12 fields, saw 14
# Skipping line 1480482: expected 12 fields, saw 13
# Skipping line 1480487: expected 12 fields, saw 14
# Skipping line 1480495: expected 12 fields, saw 15
# Skipping line 1480507: expected 12 fields, saw 19
# Skipping line 1480523: expected 12 fields, saw 13
# Skipping line 1480546: expected 12 fields, saw 13
# Skipping line 1480551: expected 12 fields, saw 13
# Skipping line 1480563: expected 12 fields, saw 17
# Skipping line 1480566: expected 12 fields, saw 14
# Skipping line 1480568: expected 12 fields, saw 13
# Skipping line 1480578: expected 12 fields, saw 15
# Skipping line 1480597: expected 12 fields, saw 14
# Skipping line 1480607: expected 12 fields, saw 23
# Skipping line 1480622: expected 12 fields, saw 15
# Skipping line 1480669: expected 12 fields, saw 13
# Skipping line 1480680: expected 12 fields, saw 15
# Skipping line 1480692: expected 12 fields, saw 13
# Skipping line 1480711: expected 12 fields, saw 14
# Skipping line 1480727: expected 12 fields, saw 15
# Skipping line 1480746: expected 12 fields, saw 18
# Skipping line 1480753: expected 12 fields, saw 15
# Skipping line 1480756: expected 12 fields, saw 23
# Skipping line 1480759: expected 12 fields, saw 13
# Skipping line 1480765: expected 12 fields, saw 14
# Skipping line 1480775: expected 12 fields, saw 14
# Skipping line 1480777: expected 12 fields, saw 15
# Skipping line 1480820: expected 12 fields, saw 20
# Skipping line 1480821: expected 12 fields, saw 15
# Skipping line 1480829: expected 12 fields, saw 14
# Skipping line 1480840: expected 12 fields, saw 18
# Skipping line 1480919: expected 12 fields, saw 13
# Skipping line 1480930: expected 12 fields, saw 14
# Skipping line 1480931: expected 12 fields, saw 13
# Skipping line 1480935: expected 12 fields, saw 13
# Skipping line 1480947: expected 12 fields, saw 18
# Skipping line 1480948: expected 12 fields, saw 13
# Skipping line 1480971: expected 12 fields, saw 16
# Skipping line 1480975: expected 12 fields, saw 19
# Skipping line 1480977: expected 12 fields, saw 13
# Skipping line 1480980: expected 12 fields, saw 17
# Skipping line 1480982: expected 12 fields, saw 16
# Skipping line 1480990: expected 12 fields, saw 13
# Skipping line 1480993: expected 12 fields, saw 13
# Skipping line 1481003: expected 12 fields, saw 15
# Skipping line 1481007: expected 12 fields, saw 24
# Skipping line 1481010: expected 12 fields, saw 14
# Skipping line 1481016: expected 12 fields, saw 13
# Skipping line 1481021: expected 12 fields, saw 14
# Skipping line 1481031: expected 12 fields, saw 14
# Skipping line 1481044: expected 12 fields, saw 15
# Skipping line 1481069: expected 12 fields, saw 14
# Skipping line 1481075: expected 12 fields, saw 14
# Skipping line 1481089: expected 12 fields, saw 14
# Skipping line 1481098: expected 12 fields, saw 17
# Skipping line 1481101: expected 12 fields, saw 15
# Skipping line 1481111: expected 12 fields, saw 13
# Skipping line 1481119: expected 12 fields, saw 15
# Skipping line 1481134: expected 12 fields, saw 13
# Skipping line 1481155: expected 12 fields, saw 14
# Skipping line 1481158: expected 12 fields, saw 17
# Skipping line 1481192: expected 12 fields, saw 13
# Skipping line 1481195: expected 12 fields, saw 22
# Skipping line 1481197: expected 12 fields, saw 20
# Skipping line 1481207: expected 12 fields, saw 14
# Skipping line 1481254: expected 12 fields, saw 17
# Skipping line 1481260: expected 12 fields, saw 14
# Skipping line 1481279: expected 12 fields, saw 13
# Skipping line 1481291: expected 12 fields, saw 13
# Skipping line 1481304: expected 12 fields, saw 14
# Skipping line 1481316: expected 12 fields, saw 22
# Skipping line 1481317: expected 12 fields, saw 16
# Skipping line 1481318: expected 12 fields, saw 18
# Skipping line 1481350: expected 12 fields, saw 19
# Skipping line 1481365: expected 12 fields, saw 13
# Skipping line 1481423: expected 12 fields, saw 16
# Skipping line 1481453: expected 12 fields, saw 16
# Skipping line 1481457: expected 12 fields, saw 14
# Skipping line 1481496: expected 12 fields, saw 13
# Skipping line 1481511: expected 12 fields, saw 13
# Skipping line 1481516: expected 12 fields, saw 13
# Skipping line 1481526: expected 12 fields, saw 14
# Skipping line 1481603: expected 12 fields, saw 14
# Skipping line 1481642: expected 12 fields, saw 13
# Skipping line 1481644: expected 12 fields, saw 15
# Skipping line 1481668: expected 12 fields, saw 13
# Skipping line 1481696: expected 12 fields, saw 13
# Skipping line 1481726: expected 12 fields, saw 13
# Skipping line 1481780: expected 12 fields, saw 19
# Skipping line 1481845: expected 12 fields, saw 19
# Skipping line 1481862: expected 12 fields, saw 15
# Skipping line 1481933: expected 12 fields, saw 13
# Skipping line 1482003: expected 12 fields, saw 15
# Skipping line 1482008: expected 12 fields, saw 13
# Skipping line 1482017: expected 12 fields, saw 13
# Skipping line 1482019: expected 12 fields, saw 14
# Skipping line 1482026: expected 12 fields, saw 13
# Skipping line 1482035: expected 12 fields, saw 14
# Skipping line 1482065: expected 12 fields, saw 14
# Skipping line 1482084: expected 12 fields, saw 13
# Skipping line 1482117: expected 12 fields, saw 13
# Skipping line 1482118: expected 12 fields, saw 14
# Skipping line 1482120: expected 12 fields, saw 14
# Skipping line 1482122: expected 12 fields, saw 13
# Skipping line 1482130: expected 12 fields, saw 13
# Skipping line 1482135: expected 12 fields, saw 13
# Skipping line 1482148: expected 12 fields, saw 14
# Skipping line 1482157: expected 12 fields, saw 13
# Skipping line 1482159: expected 12 fields, saw 13
# Skipping line 1482227: expected 12 fields, saw 15
# Skipping line 1482244: expected 12 fields, saw 13
# Skipping line 1482284: expected 12 fields, saw 13
# Skipping line 1482302: expected 12 fields, saw 15
# Skipping line 1482307: expected 12 fields, saw 13
# Skipping line 1482334: expected 12 fields, saw 13
# Skipping line 1482336: expected 12 fields, saw 13
# Skipping line 1482337: expected 12 fields, saw 18
# Skipping line 1482338: expected 12 fields, saw 14
# Skipping line 1482341: expected 12 fields, saw 16
# Skipping line 1482344: expected 12 fields, saw 20
# Skipping line 1482348: expected 12 fields, saw 13
# Skipping line 1482369: expected 12 fields, saw 13
# Skipping line 1482429: expected 12 fields, saw 17
# Skipping line 1482486: expected 12 fields, saw 13
# Skipping line 1482503: expected 12 fields, saw 14
# Skipping line 1482541: expected 12 fields, saw 19
# Skipping line 1482543: expected 12 fields, saw 14
# Skipping line 1482550: expected 12 fields, saw 15
# Skipping line 1482563: expected 12 fields, saw 13
#
#   df4 = pd.read_csv('/content/reviews.csv.gz', quoting=3, on_bad_lines='warn')
# <ipython-input-2-db760dd4b80c>:4: DtypeWarning: Columns (0,1,2,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4 = pd.read_csv('/content/reviews.csv.gz', quoting=3, on_bad_lines='warn')

# %%
# Assuming df2 is your DataFrame
df2['Occupancy_Rate'] = (365 - df2['availability_365']) / 365

# Assuming df2 is your DataFrame and you have already created the 'Occupancy_Rate' column
occupancy_rate_summary = df2['Occupancy_Rate'].describe()
print(occupancy_rate_summary)
# Out:
# count    57963.000000
# mean         0.345081
# std          0.348423
# min          0.000000
# 25%          0.016438
# 50%          0.263014
# 75%          0.567123
# max          1.000000
# Name: Occupancy_Rate, dtype: float64

# %%
print(df1.head())
print(df2.head())
print(df4.head())
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0       83038  2024-12-30         f  $50.00            NaN             4.0
# 1       83038  2024-12-31         f  $50.00            NaN             4.0
# 2       83038  2025-01-01         f  $50.00            NaN             4.0
# 3       83038  2025-01-02         f  $50.00            NaN             4.0
# 4       83038  2025-01-03         f  $50.00            NaN             4.0
#
#    maximum_nights
# 0            28.0
# 1            28.0
# 2            28.0
# 3            28.0
# 4            28.0
#       id                         listing_url       scrape_id last_scraped  \
# 0   7011   https://www.airbnb.com/rooms/7011  20241230011704   2024-12-30
# 1  22948  https://www.airbnb.com/rooms/22948  20241230011704   2024-12-30
# 2  35264  https://www.airbnb.com/rooms/35264  20241230011704   2024-12-30
# 3  43992  https://www.airbnb.com/rooms/43992  20241230011704   2024-12-30
# 4  43995  https://www.airbnb.com/rooms/43995  20241230011704   2024-12-30
#
#         source                                               name  \
# 0  city scrape               SEASIDE - Historic Antique Residence
# 1  city scrape  BnB center near station with balcony and break...
# 2  city scrape                         Etna-sea a panoramic villa
# 3  city scrape                             Two steps from the sea
# 4  city scrape                                    Villa Verdemare
#
#                                          description  \
# 0  WINEYARD WITH COLOURS OF THE SEASIDE.<br /><br...
# 1  Near the Central Station and the beginning of ...
# 2  Our country house, swathed in the greenery of ...
# 3  Very nice flat in front of the beach with a wo...
# 4  Wonderful villa that can easily accommodate up...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  The neighborhood is in a residential area, cen...
# 2  Contact with nature, relaxation, remarkable pa...
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...    16888  ...
# 1  https://a0.muscache.com/pictures/hosting/Hosti...    88837  ...
# 2  https://a0.muscache.com/pictures/7dc73c6a-7bee...   151644  ...
# 3  https://a0.muscache.com/pictures/9495798/e9cfb...   192525  ...
# 4  https://a0.muscache.com/pictures/9498289/eef27...   192525  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.72                   4.59                4.59
# 1                        4.81                   4.88                4.85
# 2                        4.81                   4.86                4.76
# 3                        4.94                   4.51                4.64
# 4                        4.92                   4.72                4.72
#
#               license instant_bookable calculated_host_listings_count  \
# 0     19081011C235687                t                             10
# 1  IT084001C1KUVGVHF9                t                              3
# 2  IT087035B5VYN4LFLN                f                              5
# 3  IT081008C26PNHNIA6                f                              2
# 4  IT081020C2NSGROBUN                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                          10
# 1                                           0
# 2                                           5
# 3                                           2
# 4                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            3
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.18
# 1                                           0              2.48
# 2                                           0              0.90
# 3                                           0              0.49
# 4                                           0              0.46
#
# [5 rows x 75 columns]
#                                    listing_id  \
# 0                                        7011
# 1  <br/>Just thank you! Thank you very much!"
# 2                                       <br/>
# 3             <br/>In the Villa near to Mozia
# 4                                       <br/>
#
#                                                   id  \
# 0                                               8283
# 1                                                NaN
# 2                                                NaN
# 3   we experienced a fantastic work in progress. ...
# 4                                                NaN
#
#                                                 date  \
# 0                                         2009-08-26
# 1                                                NaN
# 2                                                NaN
# 3   I almost had the feeling I was staying a mode...
# 4                                                NaN
#
#                                          reviewer_id reviewer_name comments
# 0                                              19620          Ivan  "Hello!
# 1                                                NaN           NaN      NaN
# 2                                                NaN           NaN      NaN
# 3   road bicycles through vine and olive fields a...           NaN      NaN
# 4                                                NaN           NaN      NaN

# %%
# For df1:
nan_count_df1 = df1.isna().sum().sum()
print("Total NaNs in df1:", nan_count_df1)

# For df2
nan_count_df2 = df2.isna().sum().sum()
print("Total NaNs in df2:", nan_count_df2)

# For df3:
nan_count_df3 = df3.isna().sum().sum()
print("Total NaNs in df3:", nan_count_df3)

# For df4:
nan_count_df4 = df4.isna().sum().sum()
print("Total NaNs in df4:", nan_count_df4)

# For df5 (geopandas DataFrame):
nan_count_df5 = df5.isna().sum().sum()
print("Total NaNs in df5:", nan_count_df5)
# Out:
# Total NaNs in df1: 21141307
# Total NaNs in df2: 564505
# Total NaNs in df3: 390
# Total NaNs in df4: 1060623
# Total NaNs in df5: 390

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57963 entries, 0 to 57962
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            57963 non-null  int64
#  1   listing_url                                   57963 non-null  object
#  2   scrape_id                                     57963 non-null  int64
#  3   last_scraped                                  57963 non-null  object
#  4   source                                        57963 non-null  object
#  5   name                                          57963 non-null  object
#  6   description                                   56172 non-null  object
#  7   neighborhood_overview                         26238 non-null  object
#  8   picture_url                                   57963 non-null  object
#  9   host_id                                       57963 non-null  int64
#  10  host_url                                      57963 non-null  object
#  11  host_name                                     57960 non-null  object
#  12  host_since                                    57960 non-null  object
#  13  host_location                                 38840 non-null  object
#  14  host_about                                    22103 non-null  object
#  15  host_response_time                            36004 non-null  object
#  16  host_response_rate                            36004 non-null  object
#  17  host_acceptance_rate                          47470 non-null  object
#  18  host_is_superhost                             56901 non-null  object
#  19  host_thumbnail_url                            57960 non-null  object
#  20  host_picture_url                              57960 non-null  object
#  21  host_neighbourhood                            1839 non-null   object
#  22  host_listings_count                           57960 non-null  float64
#  23  host_total_listings_count                     57960 non-null  float64
#  24  host_verifications                            57960 non-null  object
#  25  host_has_profile_pic                          57960 non-null  object
#  26  host_identity_verified                        57960 non-null  object
#  27  neighbourhood                                 26239 non-null  object
#  28  neighbourhood_cleansed                        57963 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      57963 non-null  float64
#  31  longitude                                     57963 non-null  float64
#  32  property_type                                 57963 non-null  object
#  33  room_type                                     57963 non-null  object
#  34  accommodates                                  57963 non-null  int64
#  35  bathrooms                                     51604 non-null  float64
#  36  bathrooms_text                                57900 non-null  object
#  37  bedrooms                                      57165 non-null  float64
#  38  beds                                          51573 non-null  float64
#  39  amenities                                     57963 non-null  object
#  40  price                                         51616 non-null  object
#  41  minimum_nights                                57963 non-null  int64
#  42  maximum_nights                                57963 non-null  int64
#  43  minimum_minimum_nights                        57963 non-null  int64
#  44  maximum_minimum_nights                        57963 non-null  int64
#  45  minimum_maximum_nights                        57963 non-null  int64
#  46  maximum_maximum_nights                        57963 non-null  int64
#  47  minimum_nights_avg_ntm                        57963 non-null  float64
#  48  maximum_nights_avg_ntm                        57963 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              56637 non-null  object
#  51  availability_30                               57963 non-null  int64
#  52  availability_60                               57963 non-null  int64
#  53  availability_90                               57963 non-null  int64
#  54  availability_365                              57963 non-null  int64
#  55  calendar_last_scraped                         57963 non-null  object
#  56  number_of_reviews                             57963 non-null  int64
#  57  number_of_reviews_ltm                         57963 non-null  int64
#  58  number_of_reviews_l30d                        57963 non-null  int64
#  59  first_review                                  40742 non-null  object
#  60  last_review                                   40742 non-null  object
#  61  review_scores_rating                          40742 non-null  float64
#  62  review_scores_accuracy                        40734 non-null  float64
#  63  review_scores_cleanliness                     40735 non-null  float64
#  64  review_scores_checkin                         40729 non-null  float64
#  65  review_scores_communication                   40731 non-null  float64
#  66  review_scores_location                        40729 non-null  float64
#  67  review_scores_value                           40726 non-null  float64
#  68  license                                       34792 non-null  object
#  69  instant_bookable                              57963 non-null  object
#  70  calculated_host_listings_count                57963 non-null  int64
#  71  calculated_host_listings_count_entire_homes   57963 non-null  int64
#  72  calculated_host_listings_count_private_rooms  57963 non-null  int64
#  73  calculated_host_listings_count_shared_rooms   57963 non-null  int64
#  74  reviews_per_month                             40742 non-null  float64
# dtypes: float64(19), int64(21), object(35)
# memory usage: 33.2+ MB

# %%
num_listings = len(df2)
print("Number of listings:", num_listings)
# Out:
# Number of listings: 57963

# %%
# Convert 'price' to numeric, removing commas and dollar signs
df2['price'] = df2['price'].str.replace('[\$,]', '', regex=True).astype(float)

avg_price = df2['price'].mean()
print("Average price of listing:", avg_price)

price_summary = df2['price'].describe()
print(price_summary)
# Out:
# Average price of listing: 305.68945675759454
# count    51616.000000
# mean       305.689457
# std       1349.657628
# min          8.000000
# 25%         61.000000
# 50%         87.000000
# 75%        137.000000
# max      80000.000000
# Name: price, dtype: float64

# %%
num_neighborhoods = df2['neighbourhood_cleansed'].nunique()
print("Number of neighborhoods:", num_neighborhoods)
# Out:
# Number of neighborhoods: 375

# %%
avg_bedrooms = df2['bedrooms'].mean()
print("Average number of bedrooms:", avg_bedrooms)
# Out:
# Average number of bedrooms: 1.7813172395696668

# %%
avg_review_score = df2['review_scores_rating'].mean()
print("Average review ratings score:", avg_review_score)
# Out:
# Average review ratings score: 4.733357223504001

# %%
num_hosts = df2['host_id'].nunique()
print("Number of hosts:", num_hosts)
# Out:
# Number of hosts: 30539

# %%
columns_to_check = ['bedrooms', 'price', 'beds', 'property_type', 'accommodates', 'minimum_nights']

for column in columns_to_check:
    nan_count = df2[column].isna().sum()
    print(f"Number of NaNs in '{column}' column:", nan_count)
# Out:
# Number of NaNs in 'bedrooms' column: 798
# Number of NaNs in 'price' column: 6347
# Number of NaNs in 'beds' column: 6390
# Number of NaNs in 'property_type' column: 0
# Number of NaNs in 'accommodates' column: 0
# Number of NaNs in 'minimum_nights' column: 0

# %%
columns_to_fill = ['bedrooms', 'beds', 'review_scores_rating', 'accommodates', 'minimum_nights']

for column in columns_to_fill:
    # Calculate the mean of the column (excluding NaNs)
    mean_value = df2[column].mean

# %%
# Assuming df2 is your DataFrame
df2['Occupancy_Rate'] = (365 - df2['availability_365']) / 365

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming df2 is your DataFrame with the 'price' column

# ----> Calculate IQR and thresholds for outlier removal <----
Q1 = df2['price'].quantile(0.25)
Q3 = df2['price'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# ----> Filter data to remove outliers <----
filtered_df2 = df2[(df2['price'] >= lower_bound) & (df2['price'] <= upper_bound)]

# Create the histogram using the filtered data
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.hist(filtered_df2['price'], bins=30, edgecolor='black')  # bins control the number of bars
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Distribution of Prices (Outliers Removed)")
plt.grid(True)  # Add a grid for better readability
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming df2 is your DataFrame with the 'Occupancy_Rate' column
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.hist(df2['Occupancy_Rate'], bins=30, edgecolor='black')  # bins control the number of bars
plt.xlabel("Occupancy Rate")
plt.ylabel("Frequency")
plt.title("Distribution of Occupancy Rates")
plt.grid(True)  # Add a grid for better readability
plt.show()

# %%
import pandas as pd

# Assuming df2 is your DataFrame with 'neighbourhood_cleansed' and 'Occupancy_Rate' columns

# Group by neighborhood and calculate average occupancy rate
neighborhood_occupancy = df2.groupby('neighbourhood_cleansed')['Occupancy_Rate'].mean().sort_values(ascending=False)

# Print the top neighborhoods with highest average occupancy rates
print("Top Neighborhoods with Highest Average Occupancy Rates:")
print(neighborhood_occupancy.head(10))  # Adjust the number to see more neighborhoods
# Out:
# Top Neighborhoods with Highest Average Occupancy Rates:
# neighbourhood_cleansed
# Godrano                    1.000000
# Alessandria della Rocca    1.000000
# Cerami                     0.835274
# Roccella Valdemone         0.816438
# Alimena                    0.753425
# Milena                     0.750685
# Gallodoro                  0.689726
# Santa Domenica Vittoria    0.667580
# Casalvecchio Siculo        0.637965
# Marianopoli                0.630137
# Name: Occupancy_Rate, dtype: float64

# %%
# Assuming df2 is your DataFrame
df2['Occupancy_Rate'] = (365 - df2['availability_365']) / 365

# %%
# Assuming df2 is your DataFrame and you have already created the 'Occupancy_Rate' column
occupancy_rate_summary = df2['Occupancy_Rate'].describe()
print(occupancy_rate_summary)
# Out:
# count    57963.000000
# mean         0.345081
# std          0.348423
# min          0.000000
# 25%          0.016438
# 50%          0.263014
# 75%          0.567123
# max          1.000000
# Name: Occupancy_Rate, dtype: float64

# %%
df2['Successful'] = (df2['Occupancy_Rate'] > 0.7).astype(int)

# %%
df2['Successful'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        1
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 57958    0
# 57959    0
# 57960    0
# 57961    0
# 57962    0
# Name: Successful, Length: 57963, dtype: int64>

# %%
columns_to_check = ['bedrooms', 'price', 'beds', 'review_scores_rating', 'accommodates', 'minimum_nights']

for column in columns_to_check:
    nan_count = df2[column].isna().sum()
    print(f"Number of NaNs in '{column}' column:", nan_count)
# Out:
# Number of NaNs in 'bedrooms' column: 798
# Number of NaNs in 'price' column: 6347
# Number of NaNs in 'beds' column: 6390
# Number of NaNs in 'review_scores_rating' column: 17221
# Number of NaNs in 'accommodates' column: 0
# Number of NaNs in 'minimum_nights' column: 0

# %%
unique_host_is_superhost = df2['host_is_superhost'].unique()
print(unique_host_is_superhost)
# Out:
# ['f' 't' nan]

# %%
nan_count_superhost = df2['host_is_superhost'].isna().sum()
print(f"Number of NaNs in 'host_is_superhost' column:", nan_count_superhost)
# Out:
# Number of NaNs in 'host_is_superhost' column: 1062

# %%
import pandas as pd

# Assuming df2 is your DataFrame with 'neighbourhood_cleansed' and 'Successful' columns
# Group by neighborhood and calculate the average success rate
neighborhood_performance = df2.groupby('neighbourhood_cleansed')['Successful'].mean().sort_values(ascending=False)

# Print the top performing neighborhoods
print("Top Performing Neighborhoods:")
print(neighborhood_performance.head(10))  # Adjust the number to see more neighborhoods

# You can also visualize the performance using a bar chart
neighborhood_performance.plot(kind='bar', figsize=(10, 6))
import matplotlib.pyplot as plt
plt.xlabel("Neighborhood")
plt.ylabel("Average Success Rate")
plt.title("Neighborhood Performance")
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.tight_layout()
plt.show()
# Out:
# Top Performing Neighborhoods:
# neighbourhood_cleansed
# Godrano                    1.000000
# Alessandria della Rocca    1.000000
# Cerami                     0.875000
# Capizzi                    0.750000
# Roccella Valdemone         0.750000
# Santa Domenica Vittoria    0.666667
# Milena                     0.666667
# Alimena                    0.666667
# Casalvecchio Siculo        0.571429
# Galati Mamertino           0.555556
# Name: Successful, dtype: float64

# %%
# Calculate total listings in Sicily
total_listings = len(df2)

# Group by neighborhood and count listings
neighborhood_counts = df2.groupby('neighbourhood')['id'].count().reset_index(name='listings_count')

# Calculate proportion and add as a new column
neighborhood_counts['proportion'] = neighborhood_counts['listings_count'] / total_listings

# Merge the proportions back into the original DataFrame (df2)
df2 = pd.merge(df2, neighborhood_counts[['neighbourhood', 'proportion']], on='neighbourhood', how='left')

# %%
# Sort by proportion and get the top 10
top_10_neighborhoods = neighborhood_counts.sort_values(by='proportion', ascending=False).head(10)

# Display the top 10
print(top_10_neighborhoods)
# Out:
#                                 neighbourhood  listings_count  proportion
# 1277                  Palermo, Sicilia, Italy            3617    0.062402
# 437                   Catania, Sicilia, Italy            1963    0.033866
# 1860                 Syracuse, Sicilia, Italy            1438    0.024809
# 392   Castellammare del Golfo, Sicilia, Italy             650    0.011214
# 1885                 Taormina, Sicilia, Italy             586    0.010110
# 1213                     Noto, Sicilia, Italy             465    0.008022
# 1955                  Trapani, Sicilia, Italy             462    0.007971
# 1032                  Marsala, Sicilia, Italy             459    0.007919
# 138                     Avola, Sicilia, Italy             373    0.006435
# 1488                   Ragusa, Sicilia, Italy             366    0.006314

# %%
target_cities = ['Syracuse', 'Catania', 'Palermo']

# Define neighboring neighborhoods for each city (replace with actual neighborhood names):
neighboring_neighborhoods = {
    'Syracuse': ['Ortigia', 'Grottasanta', 'Santa Lucia'],
    'Catania': ['Centro Storico', 'Librino', 'Picanello'],
    'Palermo': ['Centro Storico', 'Mondello', 'La Kalsa']
}

# Create a list to store listings in target areas
target_listings = []

# Iterate through each city and its neighbors
for city in target_cities:
    # Filter listings within the city
    # ----> Changed to use 'neighbourhood_cleansed' instead of 'city' <----
    city_listings = df2[df2['neighbourhood_cleansed'] == city]
    target_listings.extend(city_listings['id'].tolist())

    # Filter listings within neighboring neighborhoods
    for neighborhood in neighboring_neighborhoods[city]:
        neighborhood_listings = df2[df2['neighbourhood_cleansed'] == neighborhood]
        target_listings.extend(neighborhood_listings['id'].tolist())

# Get unique listing IDs
target_listings = list(set(target_listings))

# Count the number of listings
num_target_listings = len(target_listings)

print(f"Number of listings in target cities and neighborhoods: {num_target_listings}")
# Out:
# Number of listings in target cities and neighborhoods: 11783

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
from shapely.geometry import Point

# Define city data (replace with your desired cities and coordinates)
city_data = {
    'city': ['Catania', 'Palermo', 'Messina', 'Syracuse', 'Trapani'],
    'latitude': [37.5027, 38.1157, 38.1936, 37.0592, 38.0197],
    'longitude': [15.0873, 13.3614, 15.5542, 15.2657, 12.5393]
}

# Create a GeoDataFrame for cities
cities_gdf = gpd.GeoDataFrame(
    city_data,
    geometry=gpd.points_from_xy(city_data['longitude'], city_data['latitude']),
    crs=df5.crs  # Use the same CRS as your neighborhoods GeoDataFrame
)

# Plotting the map with both heatmap and city markers
fig, ax = plt.subplots(figsize=(10, 8))

# Heatmap layer
sns.scatterplot(x='longitude', y='latitude', hue='proportion', data=df2, palette='viridis', size='proportion', sizes=(20, 200), ax=ax)

# City markers layer
cities_gdf.plot(ax=ax, marker='o', color='red', markersize=10, label='Cities')

# Adding labels for cities
for x, y, label in zip(cities_gdf.geometry.x, cities_gdf.geometry.y, cities_gdf['city']):
    ax.text(x, y, label, fontsize=10, ha='center', va='bottom')

plt.title('Heatmap of Listing Proportions with Cities')
plt.legend()
plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Define city data (replace with your desired cities and coordinates)
city_data = {
    'city': ['Catania', 'Palermo', 'Messina', 'Syracuse', 'Trapani'],
    'latitude': [37.5027, 38.1157, 38.1936, 37.0592, 38.0197],
    'longitude': [15.0873, 13.3614, 15.5542, 15.2657, 12.5393]
}

# Create a GeoDataFrame for cities
cities_gdf = gpd.GeoDataFrame(
    city_data,
    geometry=gpd.points_from_xy(city_data['longitude'], city_data['latitude']),
    crs=df5.crs  # Use the same CRS as your neighborhoods GeoDataFrame
)

# 1. Merge Occupancy Rate with GeoDataFrame
# ----> Check if 'neighbourhood_cleansed' exists in df2,
#       if not, use the correct column name <----
if 'neighbourhood_cleansed' not in df2.columns:
    # Replace 'neighbourhood' with the actual column name in df2
    merge_column = 'neighbourhood'
else:
    merge_column = 'neighbourhood_cleansed'

merged_data = df5.merge(df2[[merge_column, 'Occupancy_Rate']],
                        left_on='neighbourhood', right_on=merge_column, how='left')

# Drop the duplicate column after merge if necessary
if merge_column != 'neighbourhood':
    merged_data = merged_data.drop(columns=[merge_column])
# 2. Create the Heatmap
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
merged_data.plot(column='Occupancy_Rate', cmap='YlOrRd', linewidth=0.8,
                 ax=ax, edgecolor='0.8', legend=True)

for x, y, label in zip(cities_gdf.geometry.x, cities_gdf.geometry.y, cities_gdf['city']):
    ax.plot(x, y, marker='o', markersize=5, color='black')
    ax.text(x, y, label, fontsize=8, ha='center', va='center')

ax.set_title('Occupancy Rate Heatmap in Sicily')
plt.show()

# %%
import pandas as pd

# Assuming you have the 'Successful' column in df2

# 1. Compare average review scores:
avg_review_scores = df2.groupby('Successful')['review_scores_rating'].mean()
print("Average Review Scores:\n", avg_review_scores)

# 2. Analyze pricing differences:
avg_price = df2.groupby('Successful')['price'].mean()
print("\nAverage Price:\n", avg_price)

# 3. Explore property types:
property_type_distribution = df2.groupby(['Successful', 'property_type'])['id'].count().reset_index(name='count')
print("\nProperty Type Distribution:\n", property_type_distribution)

# 4. Investigate host characteristics:
superhost_distribution = df2.groupby(['Successful', 'host_is_superhost'])['id'].count().reset_index(name='count')
print("\nSuperhost Distribution:\n", superhost_distribution)

# 5. Examine location and neighborhood:
neighborhood_occupancy = df2.groupby(['Successful', 'neighbourhood_cleansed'])['Occupancy_Rate'].mean().reset_index()
print("\nNeighborhood Occupancy:\n", neighborhood_occupancy)

# 6. Explore room types:
room_type_distribution = df2.groupby(['Successful', 'room_type'])['id'].count().reset_index(name='count')
print("\nRoom Type Distribution:\n", room_type_distribution)
# Out:
# Average Review Scores:
#  Successful
# 0    4.734925
# 1    4.727314
# Name: review_scores_rating, dtype: float64
#
# Average Price:
#  Successful
# 0    290.456601
# 1    405.710056
# Name: price, dtype: float64
#
# Property Type Distribution:
#       Successful          property_type  count
# 0             0                   Barn      8
# 1             0                   Boat     39
# 2             0              Camper/RV     21
# 3             0               Campsite      7
# 4             0        Casa particular     66
# ..          ...                    ...    ...
# 157           1  Shared room in hostel      3
# 158           1                   Tent      9
# 159           1              Tiny home    129
# 160           1                  Tower      1
# 161           1              Treehouse      1
#
# [162 rows x 3 columns]
#
# Superhost Distribution:
#     Successful host_is_superhost  count
# 0           0                 f  35243
# 1           0                 t  10067
# 2           1                 f   9585
# 3           1                 t   2006
#
# Neighborhood Occupancy:
#       Successful neighbourhood_cleansed  Occupancy_Rate
# 0             0                  Acate        0.259589
# 1             0         Aci Bonaccorsi        0.231880
# 2             0           Aci Castello        0.183123
# 3             0             Aci Catena        0.128135
# 4             0       Aci Sant'Antonio        0.134102
# ..          ...                    ...             ...
# 666           1              Villarosa        1.000000
# 667           1                   Vita        0.997260
# 668           1               Vittoria        0.860274
# 669           1                Vizzini        0.772603
# 670           1        Zafferana Etnea        0.941731
#
# [671 rows x 3 columns]
#
# Room Type Distribution:
#     Successful        room_type  count
# 0           0  Entire home/apt  37323
# 1           0       Hotel room    228
# 2           0     Private room   8586
# 3           0      Shared room     19
# 4           1  Entire home/apt   9397
# 5           1       Hotel room     85
# 6           1     Private room   2320
# 7           1      Shared room      5

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 2. Convert 'date' column to datetime:
df1['date'] = pd.to_datetime(df1['date'])

# 3. Subtract one year from the dates:
df1['date'] = df1['date'] - pd.DateOffset(years=1)

# 4. Filter for available listings:
available_listings = df1[df1['available'] == 't']

# Merge with df2 to get 'Successful' column
available_listings = pd.merge(available_listings, df2[['id', 'Successful']], left_on='listing_id', right_on='id', how='left')

# 5. Group by date and Successful, then count available listings:
daily_availability = available_listings.groupby(['date', 'Successful'])['listing_id'].count().reset_index(name='available_count')

# 6. Create the time series plot:
plt.figure(figsize=(12, 6))

# Plot for all listings
plt.plot(daily_availability['date'].unique(), daily_availability.groupby('date')['available_count'].sum(), label='All Listings', color='gray')

# Plot for successful listings
plt.plot(daily_availability[daily_availability['Successful'] == 1]['date'],
         daily_availability[daily_availability['Successful'] == 1]['available_count'],
         label='Successful Listings', color='green')

# Plot for unsuccessful listings
plt.plot(daily_availability[daily_availability['Successful'] == 0]['date'],
         daily_availability[daily_availability['Successful'] == 0]['available_count'],
         label='Unsuccessful Listings', color='red')

plt.xlabel("Date")
plt.ylabel("Number of Available Listings")
plt.title("Daily Availability of Listings")
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# ----> Calculate IQR and thresholds for outlier removal <----
Q1 = df2['price'].quantile(0.25)
Q3 = df2['price'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Calculate the median price
median_price = filtered_df2['price'].median()



# ----> Filter data to remove outliers <----
filtered_df2 = df2[(df2['price'] >= lower_bound) & (df2['price'] <= upper_bound)]

# Create the histogram using the filtered data
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.hist(filtered_df2['price'], bins=30, edgecolor='black')  # bins control the number of bars
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.axvline(median_price, color='red', linestyle='dashed', linewidth=2, label=f'Median Price: {median_price:.2f}')
plt.legend()
plt.title("Distribution of Prices (Outliers Removed)")
plt.grid(True)  # Add a grid for better readability
plt.show()

# %%
# Convert 'listing_id' in df4 to int64, handling errors
df4['listing_id'] = pd.to_numeric(df4['listing_id'], errors='coerce').astype('Int64')

# Now perform the merge
merged_df = pd.merge(df4, df2[['id', 'Successful']], left_on='listing_id', right_on='id', how='left')

# %%
successful_reviews = merged_df[merged_df['Successful'] == 1]
unsuccessful_reviews = merged_df[merged_df['Successful'] == 0]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Merge df1 (calendar) and df2 (listings)
# Convert 'listing_id' in df1 to int64
df1['listing_id'] = df1['listing_id'].astype('int64')
merged_df = pd.merge(df1, df2[['id', 'Successful', 'price']], left_on='listing_id', right_on='id', how='left')

# 2. Convert 'date' to datetime and subtract one year
merged_df['date'] = pd.to_datetime(merged_df['date'])
merged_df['date'] = merged_df['date'] - pd.DateOffset(years=1)

# 3. Filter for available listings
available_listings = merged_df[merged_df['available'] == 't']

# ----> Change 2: Group by date and Successful, calculate average price <----
# Use 'price_y' for the average price calculation as it's from df2
# (listings data) and likely contains the correct price information.
daily_avg_price = available_listings.groupby(['date', 'Successful'])['price_y'].mean().reset_index()

# 6. Calculate annual revenue (assuming price is daily rate)
daily_avg_price['annual_revenue'] = daily_avg_price['price_y'] * 365

# 7. Create time series plots
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot average price
ax1.plot(daily_avg_price[daily_avg_price['Successful'] == 1]['date'],
         daily_avg_price[daily_avg_price['Successful'] == 1]['price_y'],
         label='Successful Listings', color='blue')
ax1.plot(daily_avg_price[daily_avg_price['Successful'] == 0]['date'],
         daily_avg_price[daily_avg_price['Successful'] == 0]['price_y'],
         label='Unsuccessful Listings', color='red')
ax1.set_xlabel("Date")
ax1.set_ylabel("Average Price", color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Create a second y-axis for annual revenue
ax2 = ax1.twinx()
ax2.plot(daily_avg_price[daily_avg_price['Successful'] == 1]['date'],
         daily_avg_price[daily_avg_price['Successful'] == 1]['annual_revenue'],
         linestyle='--', color='blue')
ax2.plot(daily_avg_price[daily_avg_price['Successful'] == 0]['date'],
         daily_avg_price[daily_avg_price['Successful'] == 0]['annual_revenue'],
         linestyle='--', color='red')
ax2.set_ylabel("Annual Revenue", color='red')
ax2.tick_params(axis='y', labelcolor='red')

plt.title("Average Price and Annual Revenue of Successful vs. Unsuccessful Listings")
fig.tight_layout()
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-39-791df54df391>:51: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ... (your existing code for merging, filtering, and calculating daily_avg_price) ...

# Calculate average price for successful listings
avg_price_successful = daily_avg_price[daily_avg_price['Successful'] == 1]['price_y'].mean()

# Calculate average price for unsuccessful listings
avg_price_unsuccessful = daily_avg_price[daily_avg_price['Successful'] == 0]['price_y'].mean()

print(f"Average Price for Successful Listings: ${avg_price_successful:.2f}")
print(f"Average Price for Unsuccessful Listings: ${avg_price_unsuccessful:.2f}")

# ... (your existing code for plotting) ...
# Out:
# Average Price for Successful Listings: $405.92
# Average Price for Unsuccessful Listings: $259.92

# %%
# !pip install langdetect
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from langdetect import detect
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab') # Download the missing 'punkt_tab' resource

def preprocess_text(text):
    # 1. Detect the language of the comment
    try:
        language = detect(text)
        if language != 'en':
            return '' # Return empty string for non-English comments
    except:
        return '' # Return empty string if language detection fails

    # 2. Lowercase the text
    text = text.lower()
    # 3. Remove punctuation and special characters
    text = re.sub(r'[^\w\s]', '', text)
    # 4. Tokenize the text
    tokens = nltk.word_tokenize(text)
    # 5. Remove stop words
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    # 6. Stem the tokens
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens]
    # 7. Join the tokens back into a string
    preprocessed_text = ' '.join(tokens)
    return preprocessed_text

df4['preprocessed_comments'] = df4['comments'].apply(preprocess_text)

# Remove rows with empty preprocessed comments (non-English comments)
reviews = df4[df4['preprocessed_comments'] != '']
# Out:
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 13.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from langdetect) (1.17.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=eef29b385c6fc9fd549123a26cc4ce51ce1d667dbff21f758f83c9149d2a7e38
#   Stored in directory: /root/.cache/pip/wheels/0a/f2/b2/e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
# !pip install wordcloud
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# Function to generate word cloud
def generate_wordcloud(text, title):
    stopwords = set(STOPWORDS)
    wordcloud = WordCloud(width = 800, height = 800,
                    background_color ='white',
                    stopwords = stopwords,
                    min_font_size = 10).generate(text)

    # plot the WordCloud image
    plt.figure(figsize = (8, 8), facecolor = None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad = 0)
    plt.title(title, fontsize=20)
    plt.show()

# Generate word cloud for successful reviews
successful_text = " ".join(successful_reviews['preprocessed_comments'].astype(str).tolist())
generate_wordcloud(successful_text, "Word Cloud for Successful Listings")

# Generate word cloud for unsuccessful reviews
unsuccessful_text = " ".join(unsuccessful_reviews['preprocessed_comments'].astype(str).tolist())
generate_wordcloud(unsuccessful_text, "Word Cloud for Unsuccessful Listings")
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.11/dist-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from wordcloud) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
